# %% [markdown]
# ## 당뇨병 여부 판단
# - 이상치 처리 (Glucose, BloodPressure, SkinThickness, Insulin, BMI가 0인 값)

# %% [markdown]
# ## [참고]작업형2 문구
# - 출력을 원하실 경우 print() 함수 활용
# - 예시) print(df.head())
# - getcwd(), chdir() 등 작업 폴더 설정 불필요
# - 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가
#
# ### 데이터 파일 읽기 예제
# - import pandas as pd
# - X_test = pd.read_csv("data/X_test.csv")
# - X_train = pd.read_csv("data/X_train.csv")
# - y_train = pd.read_csv("data/y_train.csv")
#
# ### 사용자 코딩
#
# ### 답안 제출 참고
# - 아래 코드 예측변수와 수험번호를 개인별로 변경하여 활용
# - pd.DataFrame({'cust_id': X_test.cust_id, 'gender': pred}).to_csv('003000000.csv', index=False)

# %%
# 시험환경 세팅 (코드 변경 X)
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

def exam_data_load(df, target, id_name="", null_name=""):
    if id_name == "":
        df = df.reset_index().rename(columns={"index": "id"})
        id_name = 'id'
    else:
        id_name = id_name

    if null_name != "":
        df[df == null_name] = np.nan

    X_train, X_test = train_test_split(df, test_size=0.2, random_state=2021)

    y_train = X_train[[id_name, target]]
    X_train = X_train.drop(columns=[target])


    y_test = X_test[[id_name, target]]
    X_test = X_test.drop(columns=[target])
    return X_train, X_test, y_train, y_test

df = pd.read_csv("diabetes.csv")
X_train, X_test, y_train, y_test = exam_data_load(df, target='Outcome')

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((614, 9), (154, 9), (614, 2), (154, 2))

# %% [markdown]
# ## Start

# %%
# 이상치 처리: Glucose, BloodPressure, SkinThickness, Insulin, BMI가 0인 값

# %%
import pandas as pd
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((614, 9), (614, 2), (154, 9))

# %%
X_train.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 147  147            2      106             64             35      119  30.5
# 344  344            8       95             72              0        0  36.8
# 390  390            1      100             66             29      196  32.0
# 150  150            1      136             74             50      204  37.4
# 132  132            3      170             64             37      225  34.5
#
#      DiabetesPedigreeFunction  Age
# 147                     1.400   34
# 344                     0.485   57
# 390                     0.444   42
# 150                     0.399   24
# 132                     0.356   30

# %%
y_train.head()
# Out:
#       id  Outcome
# 147  147        0
# 344  344        0
# 390  390        0
# 150  150        0
# 132  132        1

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, 147 to 116
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        614 non-null    int64
#  1   Pregnancies               614 non-null    int64
#  2   Glucose                   614 non-null    int64
#  3   BloodPressure             614 non-null    int64
#  4   SkinThickness             614 non-null    int64
#  5   Insulin                   614 non-null    int64
#  6   BMI                       614 non-null    float64
#  7   DiabetesPedigreeFunction  614 non-null    float64
#  8   Age                       614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 48.0 KB

# %%
X_train.isnull().sum()
# Out:
# id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
# Glucose, BloodPressure, SkinThickness, Insulin, BMI가 0인 값
gl = len(X_train[X_train['Glucose'] == 0])
bl = len(X_train[X_train['BloodPressure'] == 0])
sk = len(X_train[X_train['SkinThickness'] == 0 ])
ins = len(X_train[X_train['Insulin'] == 0 ])
bmi = len(X_train[X_train['BMI'] == 0])

print("Glucose :" + str(gl))
print("BloodPressure :" + str(bl))
print("SkinThickness :" + str(sk))
print("Insulin :" + str(ins))
print("BMI :" + str(bmi))
# Out:
# Glucose :5
# BloodPressure :31
# SkinThickness :175
# Insulin :287
# BMI :9

# %%
# test
gl = len(X_test[X_test['Glucose'] == 0])
bl = len(X_test[X_test['BloodPressure'] == 0])
sk = len(X_test[X_test['SkinThickness'] == 0 ])
ins = len(X_test[X_test['Insulin'] == 0 ])
bmi = len(X_test[X_test['BMI'] == 0])

print("Glucose :" + str(gl))
print("BloodPressure :" + str(bl))
print("SkinThickness :" + str(sk))
print("Insulin :" + str(ins))
print("BMI :" + str(bmi))
# Out:
# Glucose :0
# BloodPressure :4
# SkinThickness :52
# Insulin :87
# BMI :2

# %%
# X_train의 Glucose 삭제
glu_index = X_train[X_train['Glucose'] == 0].index
# print(glu_index) Index([182, 75, 342, 502, 349], dtype='int64')

X_train = X_train.drop(index = glu_index, axis=0)
y_train = y_train.drop(index = glu_index, axis=0)
X_train.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 147  147            2      106             64             35      119  30.5
# 344  344            8       95             72              0        0  36.8
# 390  390            1      100             66             29      196  32.0
# 150  150            1      136             74             50      204  37.4
# 132  132            3      170             64             37      225  34.5
#
#      DiabetesPedigreeFunction  Age
# 147                     1.400   34
# 344                     0.485   57
# 390                     0.444   42
# 150                     0.399   24
# 132                     0.356   30

# %%
X_train.shape, y_train.shape
# Out:
# ((609, 9), (609, 2))

# %%
cols = ["BloodPressure", "SkinThickness", "Insulin", "BMI"]
cols_mean = X_train[cols].mean()
# print(cols_mean)
X_train[cols] = X_train[cols].replace(0, cols_mean)
X_train.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 147  147            2      106           64.0       35.00000  119.000000
# 344  344            8       95           72.0       20.91133   82.866995
# 390  390            1      100           66.0       29.00000  196.000000
# 150  150            1      136           74.0       50.00000  204.000000
# 132  132            3      170           64.0       37.00000  225.000000
#
#       BMI  DiabetesPedigreeFunction  Age
# 147  30.5                     1.400   34
# 344  36.8                     0.485   57
# 390  32.0                     0.444   42
# 150  37.4                     0.399   24
# 132  34.5                     0.356   30

# %%
gl = len(X_train[X_train['Glucose'] == 0])
bl = len(X_train[X_train['BloodPressure'] == 0])
sk = len(X_train[X_train['SkinThickness'] == 0 ])
ins = len(X_train[X_train['Insulin'] == 0 ])
bmi = len(X_train[X_train['BMI'] == 0])

print("Glucose :" + str(gl))
print("BloodPressure :" + str(bl))
print("SkinThickness :" + str(sk))
print("Insulin :" + str(ins))
print("BMI :" + str(bmi))
# Out:
# Glucose :0
# BloodPressure :0
# SkinThickness :0
# Insulin :0
# BMI :0

# %%
X_test.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 258  258            1      193             50             16      375  25.9
# 220  220            0      177             60             29      478  34.6
# 438  438            1       97             70             15        0  18.2
# 130  130            4      173             70             14      168  29.7
# 730  730            3      130             78             23       79  28.4
#
#      DiabetesPedigreeFunction  Age
# 258                     0.655   24
# 220                     1.072   21
# 438                     0.147   21
# 130                     0.361   33
# 730                     0.323   34

# %%
gl = len(X_test[X_test['Glucose'] == 0])
bl = len(X_test[X_test['BloodPressure'] == 0])
sk = len(X_test[X_test['SkinThickness'] == 0 ])
ins = len(X_test[X_test['Insulin'] == 0 ])
bmi = len(X_test[X_test['BMI'] == 0])

print("Glucose :" + str(gl))
print("BloodPressure :" + str(bl))
print("SkinThickness :" + str(sk))
print("Insulin :" + str(ins))
print("BMI :" + str(bmi))
# Out:
# Glucose :0
# BloodPressure :4
# SkinThickness :52
# Insulin :87
# BMI :2

# %%
cols = ["BloodPressure", "SkinThickness", "Insulin", "BMI"]
cols_mean = X_test[cols].mean()
X_test[cols] = X_test[cols].replace(0, cols_mean)
X_test.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 258  258            1      193           50.0           16.0  375.00000  25.9
# 220  220            0      177           60.0           29.0  478.00000  34.6
# 438  438            1       97           70.0           15.0   70.11039  18.2
# 130  130            4      173           70.0           14.0  168.00000  29.7
# 730  730            3      130           78.0           23.0   79.00000  28.4
#
#      DiabetesPedigreeFunction  Age
# 258                     0.655   24
# 220                     1.072   21
# 438                     0.147   21
# 130                     0.361   33
# 730                     0.323   34

# %%
gl = len(X_test[X_test['Glucose'] == 0])
bl = len(X_test[X_test['BloodPressure'] == 0])
sk = len(X_test[X_test['SkinThickness'] == 0 ])
ins = len(X_test[X_test['Insulin'] == 0 ])
bmi = len(X_test[X_test['BMI'] == 0])

print("Glucose :" + str(gl))
print("BloodPressure :" + str(bl))
print("SkinThickness :" + str(sk))
print("Insulin :" + str(ins))
print("BMI :" + str(bmi))
# Out:
# Glucose :0
# BloodPressure :0
# SkinThickness :0
# Insulin :0
# BMI :0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
X_train[cols] = scaler.fit_transform(X_train[cols])
X_test[cols] = scaler.fit_transform(X_test[cols])

# id
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age

# %%
X_train.drop('id', axis=1)
X_test.drop('id', axis=1)
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 258    -0.864136  2.253680      -1.788448      -0.958939  3.035900 -0.879277
# 220    -1.167964  1.748304      -1.019241       0.411848  4.214638  0.264870
# 438    -0.864136 -0.778574      -0.250034      -1.064385 -0.453274 -1.891913
# 130     0.047350  1.621960      -0.250034      -1.169830  0.666980 -0.379535
# 730    -0.256479  0.263763       0.365331      -0.220823 -0.351541 -0.550499
# ..           ...       ...            ...            ...       ...       ...
# 678    -0.256479 -0.020510      -1.634607      -0.667938 -0.453274  0.448986
# 500    -0.560307 -0.146854       1.288379      -0.642604 -0.443093 -0.971335
# 256    -0.256479 -0.336370      -1.326924       1.466300 -0.453274 -0.326930
# 80     -0.256479 -0.273198      -2.249972      -1.275275 -0.453274 -1.339566
# 174    -0.560307 -1.473465      -0.711558      -0.115378 -0.626198 -0.379535
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
y_train.head()
# Out:
#       id  Outcome
# 147  147        0
# 344  344        0
# 390  390        0
# 150  150        0
# 132  132        1

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train, y_train['Outcome'])
pred = model.predict(X_test)
model.score(X_train, y_train['Outcome'])
# Out:
# 0.6568144499178982

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=10, min_samples_leaf=4, random_state=42)
model_rf.fit(X_train, y_train['Outcome'])
pred_rf = model_rf.predict(X_test)
model_rf.score(X_train, y_train['Outcome'])
# Out:
# 0.9195402298850575

# %%
pd.DataFrame({'idx':X_test.index, 'Outcome':pred_rf}).to_csv('choicho.csv')

# %% [markdown]
# ## 라이브러리 및 데이터 불러오기

# %%
# 라이브러리
import pandas as pd

# %%
# 데이터 불러오기 (생략)
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((614, 9), (614, 2), (154, 9))

# %% [markdown]
# ## EDA

# %%
X_train.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 147  147            2      106             64             35      119  30.5
# 344  344            8       95             72              0        0  36.8
# 390  390            1      100             66             29      196  32.0
# 150  150            1      136             74             50      204  37.4
# 132  132            3      170             64             37      225  34.5
#
#      DiabetesPedigreeFunction  Age
# 147                     1.400   34
# 344                     0.485   57
# 390                     0.444   42
# 150                     0.399   24
# 132                     0.356   30

# %%
y_train.value_counts()
# Out:
# id   Outcome
# 0    1          1
# 514  0          1
# 504  0          1
# 506  1          1
# 507  0          1
#                ..
# 265  0          1
# 266  1          1
# 267  0          1
# 268  0          1
# 766  1          1
# Length: 614, dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 614 entries, 147 to 116
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        614 non-null    int64
#  1   Pregnancies               614 non-null    int64
#  2   Glucose                   614 non-null    int64
#  3   BloodPressure             614 non-null    int64
#  4   SkinThickness             614 non-null    int64
#  5   Insulin                   614 non-null    int64
#  6   BMI                       614 non-null    float64
#  7   DiabetesPedigreeFunction  614 non-null    float64
#  8   Age                       614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 48.0 KB

# %%
X_train.isnull().sum()
# Out:
# id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X_train.describe()
# Out:
#                id  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# count  614.000000   614.000000  614.000000     614.000000     614.000000
# mean   386.978827     3.845277  120.705212      68.530945      20.982085
# std    219.881344     3.388952   32.047977      19.761915      15.965031
# min      0.000000     0.000000    0.000000       0.000000       0.000000
# 25%    196.500000     1.000000   99.000000      62.000000       0.000000
# 50%    388.000000     3.000000  117.000000      72.000000      23.000000
# 75%    575.750000     6.000000  140.000000      80.000000      33.000000
# max    766.000000    17.000000  199.000000     114.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction         Age
# count  614.000000  614.000000                614.000000  614.000000
# mean    82.229642   31.948534                  0.477471   33.319218
# std    116.525772    7.734385                  0.339811   11.940953
# ...

# %% [markdown]
# ## 데이터 전처리

# %%
#이상치 처리
#Train
print('Glucose:',len(X_train[X_train['Glucose']==0]))
print('BloodPressure:',len(X_train[X_train['BloodPressure']==0]))
print('SkinThickness:',len(X_train[X_train['SkinThickness']==0]))
print('Insulin:',len(X_train[X_train['Insulin']==0]))
print('BMI:',len(X_train[X_train['BMI']==0]))
# Out:
# Glucose: 5
# BloodPressure: 31
# SkinThickness: 175
# Insulin: 287
# BMI: 9

# %%
#Test
print('Glucose:',len(X_test[X_test['Glucose']==0]))
print('BloodPressure:',len(X_test[X_test['BloodPressure']==0]))
print('SkinThickness:',len(X_test[X_test['SkinThickness']==0]))
print('Insulin:',len(X_test[X_test['Insulin']==0]))
print('BMI:',len(X_test[X_test['BMI']==0]))
# Out:
# Glucose: 0
# BloodPressure: 4
# SkinThickness: 52
# Insulin: 87
# BMI: 2

# %% [markdown]
# 트레인에만 0이 있는 포도당(Glucose)는 삭제
# 나머지는 평균값으로 대체 하여 이상치를 처리함

# %%
# 포도당 이상치 삭제
del_idx = X_train[(X_train['Glucose']==0)].index
del_idx
# Out:
# Index([182, 75, 342, 502, 349], dtype='int64')

# %%
print('Glucose 이상치 삭제 전 :', X_train.shape, y_train.shape)
X_train = X_train.drop(index=del_idx, axis=0)
y_train = y_train.drop(index=del_idx, axis=0)
print('Glucose 이상치 삭제 후 :', X_train.shape, y_train.shape)
# Out:
# Glucose 이상치 삭제 전 : (614, 9) (614, 2)
# Glucose 이상치 삭제 후 : (609, 9) (609, 2)

# %%
X_train.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 147  147            2      106             64             35      119  30.5
# 344  344            8       95             72              0        0  36.8
# 390  390            1      100             66             29      196  32.0
# 150  150            1      136             74             50      204  37.4
# 132  132            3      170             64             37      225  34.5
#
#      DiabetesPedigreeFunction  Age
# 147                     1.400   34
# 344                     0.485   57
# 390                     0.444   42
# 150                     0.399   24
# 132                     0.356   30

# %%
# 포도당을 제외한 이상치, 평균값으로 대체
cols = ['BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
cols_mean = X_train[cols].mean()
X_train.loc[:, cols].replace(0, cols_mean, inplace=True)
# 또는 X_train[cols] = X_train[cols].replace(0, cols_mean)

# %%
# 스케일링
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
X_train[cols] = scaler.fit_transform(X_train[cols])
X_test[cols] = scaler.fit_transform(X_test[cols])

# %%
# id 제외
X = X_train.drop('id',axis=1)
test = X_test.drop('id',axis=1)

# %%
from sklearn.svm import SVC
model = SVC(random_state=2022)
model.fit(X, y_train['Outcome'])
predictions = model.predict(test)

# %%
# 오버피팅 되었을 경우에 점수가 잘나올 수 있음 (객관적인 평가 아님, 밸리데이션 데이터로 평가 필요함)
round(model.score(X, y_train['Outcome']) * 100, 2)
# Out:
# 83.42

# %%
output = pd.DataFrame({'idx': X_test.index, 'Outcome': predictions})
output.head()
# Out:
#    idx  Outcome
# 0  258        1
# 1  220        1
# 2  438        0
# 3  130        1
# 4  730        0

# %%
# 수험번호.csv로 출력
output.to_csv('1234567.csv', index=False)

# %% [markdown]
# ## 결과 체점 (수험자는 알 수 없는 부분임)

# %%
round(model.score(test, y_test['Outcome']) * 100, 2) # 60점대로 낮은 정확도를 보여줌
# Out:
# 76.62
