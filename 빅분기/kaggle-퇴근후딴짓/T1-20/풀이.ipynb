# %% [markdown]
# ## 고객과 잘 맞는 타입 추천 :)
# ### basic1 데이터와 basic3 데이터를 'f4'값을 기준으로 병합하고,
# ### 병합한 데이터에서 r2결측치를 제거한다음, 앞에서 부터 20개 데이터를 선택하고 'f2'컬럼 합을 구하시오
#
# - basic1.csv: 고객 데이터
# - basic3.csv: 잘 어울리는 관계 데이터 (추천1:r1, 추천2:r2)

# %%
import pandas as pd
df1 = pd.read_csv("basic1.csv")
df2 = pd.read_csv("basic3.csv")

df1.head()
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869

# %%
df2.head()
# Out:
#      f4    r1    r2
# 0  INFP  ENFJ  ENTJ
# 1  ENFP  INFJ   NaN
# 2  INFJ  ENFP  ENTP
# 3  ENFJ  INFP  ISFP
# 4  INTJ  ENFP  ENTP

# %%
df = pd.merge(left=df1, right=df2, how='left', on='f4')
df.head()
# Out:
#      id   age city    f1  f2   f3    f4         f5    r1    r2
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791  INFP  ISFP
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826  INFP  ISFP
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986  ESFP   NaN
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078  ENFJ  ENTJ
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869  ESFP  ESTP

# %%
# Out:
#       id   age city     f1  f2   f3    f4         f5    r1    r2
# 0   id01   2.0   서울    NaN   0  NaN  ENFJ  91.297791  INFP  ISFP
# 1   id02   9.0   서울   70.0   1  NaN  ENFJ  60.339826  INFP  ISFP
# 2   id03  27.0   서울   61.0   1  NaN  ISTJ  17.252986  ESFP   NaN
# 3   id04  75.0   서울    NaN   2  NaN  INFP  52.667078  ENFJ  ENTJ
# 4   id05  24.0   서울   85.0   2  NaN  ISFJ  29.269869  ESFP  ESTP
# 5   id06  22.0   서울   57.0   0  vip  INTP  20.129444  ENTJ  ESTJ
# 6   id07  36.3   서울   60.0   1  NaN  ISFJ   9.796378  ESFP  ESTP
# 7   id08  38.0   서울  101.0   1  NaN  INFJ  83.685380  ENFP  ENTP
# 8   id09   3.3   서울   35.0   2  NaN  ESFJ  17.252986  ISFP  ISTP
# 9   id10  95.0   서울   74.0   1  NaN  ISFP  98.429899  ENFJ  ESFJ
# 10  id11  40.0   서울   68.0   0  NaN  ENFP  98.429899  INFJ   NaN
# 11  id12  20.0   서울    NaN   0  NaN  ESTP  91.297791  ISFJ  ISTJ
# 12  id13  15.0   서울   68.0   0  NaN  ESFJ  83.685380  ISFP  ISTP
# 13  id14  77.0   서울   50.0   1  NaN  ENTJ  67.886373  INFP   NaN
# 14  id15  22.0   서울   67.0   1  NaN  ENTP   9.796378  INFJ  INTJ
# 15  id16  68.0   서울   85.0   0  NaN  ESFP  16.283854  ISFJ  ISTJ
# 16  id17  74.0   서울    NaN   1  NaN  ISTP  67.886373  ESFJ   NaN
# 17  id18  41.0   서울   87.0   2  NaN  ISFJ  80.138280  ESFP  ESTP
# 18  id19  53.0   서울    NaN   0  NaN  ISFP  83.685380  ENFJ  ESFJ
# 19  id20  11.0   서울   51.0   1  NaN  INTJ  91.297791  ENFP  ENTP

# %%
df_drop = df.dropna(subset='r2')
df_drop
# Out:
#        id    age city    f1  f2   f3    f4         f5    r1    r2
# 0    id01    2.0   서울   NaN   0  NaN  ENFJ  91.297791  INFP  ISFP
# 1    id02    9.0   서울  70.0   1  NaN  ENFJ  60.339826  INFP  ISFP
# 3    id04   75.0   서울   NaN   2  NaN  INFP  52.667078  ENFJ  ENTJ
# 4    id05   24.0   서울  85.0   2  NaN  ISFJ  29.269869  ESFP  ESTP
# 5    id06   22.0   서울  57.0   0  vip  INTP  20.129444  ENTJ  ESTJ
# ..    ...    ...  ...   ...  ..  ...   ...        ...   ...   ...
# 94   id95   77.0   경기  43.0   1  NaN  INTJ  91.297791  ENFP  ENTP
# 96   id97  100.0   경기   NaN   0  NaN  INFP  67.886373  ENFJ  ENTJ
# 97   id98   39.0   경기  58.0   2  NaN  INFP  98.429899  ENFJ  ENTJ
# 98   id99    1.0   경기  47.0   0  NaN  ESFJ  97.381034  ISFP  ISTP
# 99  id100   47.0   경기  53.0   0  vip  ESFP  33.308999  ISFJ  ISTJ
#
# [83 rows x 10 columns]

# %%
df_20 = df.head(20)
df_20
# Out:
#       id   age city     f1  f2   f3    f4         f5    r1    r2
# 0   id01   2.0   서울    NaN   0  NaN  ENFJ  91.297791  INFP  ISFP
# 1   id02   9.0   서울   70.0   1  NaN  ENFJ  60.339826  INFP  ISFP
# 2   id03  27.0   서울   61.0   1  NaN  ISTJ  17.252986  ESFP   NaN
# 3   id04  75.0   서울    NaN   2  NaN  INFP  52.667078  ENFJ  ENTJ
# 4   id05  24.0   서울   85.0   2  NaN  ISFJ  29.269869  ESFP  ESTP
# 5   id06  22.0   서울   57.0   0  vip  INTP  20.129444  ENTJ  ESTJ
# 6   id07  36.3   서울   60.0   1  NaN  ISFJ   9.796378  ESFP  ESTP
# 7   id08  38.0   서울  101.0   1  NaN  INFJ  83.685380  ENFP  ENTP
# 8   id09   3.3   서울   35.0   2  NaN  ESFJ  17.252986  ISFP  ISTP
# 9   id10  95.0   서울   74.0   1  NaN  ISFP  98.429899  ENFJ  ESFJ
# 10  id11  40.0   서울   68.0   0  NaN  ENFP  98.429899  INFJ   NaN
# 11  id12  20.0   서울    NaN   0  NaN  ESTP  91.297791  ISFJ  ISTJ
# 12  id13  15.0   서울   68.0   0  NaN  ESFJ  83.685380  ISFP  ISTP
# 13  id14  77.0   서울   50.0   1  NaN  ENTJ  67.886373  INFP   NaN
# 14  id15  22.0   서울   67.0   1  NaN  ENTP   9.796378  INFJ  INTJ
# 15  id16  68.0   서울   85.0   0  NaN  ESFP  16.283854  ISFJ  ISTJ
# 16  id17  74.0   서울    NaN   1  NaN  ISTP  67.886373  ESFJ   NaN
# 17  id18  41.0   서울   87.0   2  NaN  ISFJ  80.138280  ESFP  ESTP
# 18  id19  53.0   서울    NaN   0  NaN  ISFP  83.685380  ENFJ  ESFJ
# 19  id20  11.0   서울   51.0   1  NaN  INTJ  91.297791  ENFP  ENTP

# %%
df_sum = df_20['f2'].sum()
df_sum
# Out:
# 17

# %%
# 앞에서 부터 20개 데이터를 선택하고 'f2'컬럼 합
print(df.iloc[:20]['f2'].sum())
# Out:
# 17
