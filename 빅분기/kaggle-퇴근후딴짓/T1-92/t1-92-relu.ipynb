# %% [markdown]
# ## basic1 데이터에서 age 값에 ReLU 함수를 적용하고, city가 부산인 (변경된)age의 평균을 구하시오! (소수점 둘째자리까지 출력, 절사)

# %% [markdown]
# ![image.png](attachment:d20b5e89-bba4-4d36-a7c6-c468147815ea.png)

# %% [markdown]
# ### ReLU 함수
# h(x) =
# - x (x > 0) : 0보다 크면 x
# - 0 (x <= 0) : 0이거나 0보다 작으면 0,

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../input/bigdatacertificationkr/basic1.csv")

def relu(x):
    return np.maximum(0, x)

df['age'] = df['age'].apply(relu)

cond = df['city'] == "부산"
print(int(df[cond]['age'].mean()))
# Out:
# 49
