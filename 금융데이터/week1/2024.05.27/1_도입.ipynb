# %% [markdown]
# # 크롤링의 종류
#
#
#
# ## 1. 정적 크롤링
# - 웹에 있는 정적인 데이터를 수집할 때 사용
#     - 정적인 데이터란 로그인과 같은 사전 작업 없이 바로 볼 수 있는 데이터
#     - 새로고침을 하지 않는 이상 변하지 않는 데이터
#     - 주소를 통해 요청받고 결과를 전달해 주고 종료
#
#
#
# ## 2. 동적 크롤링
# - 웹에 있는 동적인 데이터를 수집할 때 사용
#     - 동적인 데이터는 입력, 클릭, 로그인과 같이 페이지 이동시 얻을 수 있는 데이터
#     - 단계적 접근이 필요하기 때문에 수집 속도가 느리지만 수집 대상에 한계가 거의 없다는 큰 장점
#     - 연속적인 접근이 가능, 페이지 이동이 필수적이거나 페이지 안에 정보가 은닉되어 있을 경우 사용
#
#
# |           | 정적 크롤링            | 동적 크롤링                     |
# |-----------|------------------------|---------------------------------|
# | 연속성    | 주소를 통한 단발적 접근 || 브라우저를 사용한 연속적 접근 |
# | 속도      | 빠름                    | 느림                          |
# | 수집 성능 | 수집 대상에 한계가 있음 | 수집 대상에 한계가 거의 없음  |

# %%
# client -> server

# %% [markdown]
# # 라이브러리
#
# ## 1. time 라이브러리
#
# - time.time() : time.time()은 UTC를 사용해 현재 시간을 실수 형태로 돌려주는 함수이다.
#     - 1970년 1월 1일 0시 0분 0초 기준으로 지난 시간을 초 단위로 return
#
#     ```python
#     import time
#     print(time.time())
#     ```
#
# - time.localtime() : 현재 시간을 년, 월, 일, 시, 분, 초..의 형태로 출력
#
#     ```python
#     import time
#     print(time.localtime())
#     ```
#
#
#
# ## 2.정적 클로링 도구
# - requests : 간편한 HTTP 요청 처리를 하는 라이브러리, 웹서비스와 연결하기 위해 사용
# - beautifulsoup : html 태그를 처리하는 라이브러리, 웹에 있는 데이터 중 필요한 데이터만 추출하기 위해 사용
# - pd.read_html : html 내의 table만 추출할수 있는 도구
#
#
# ## 3. 동적 크롤링 도구
# - selenium : 웹 드라이버를 사용해 자동화 기능을 실현하는 라이브러리
#     - 웹에 접속해 클릭, 이동과 같은 action을 제어
#     - driver 를 설치하고 이를통해 제어 가능
# - playwright : microsoft 에서 개발한 웹테스팅 도구
#
# ## 4. multiprocessing 모듈
# - multiprocessing : 프로세스를 병렬로 실행하기 위해 사용하는 도구

# %% [markdown]
# # Web Page가져오기
# - urllib.request 패키지

# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup as bs

# %%
html = urlopen("https://www.naver.com/")

# %%
html

# %%
soup = bs(html, "html.parser") # html 태그를 찾아서 가공하기 위해 "html.parser" 를 사용해 변환

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240502.css" rel="stylesheet"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"잠 부족한 다음날 절대 하면 안 되는 것","url":"https://post.naver.com/viewer/postView.naver?volumeNo=37858679&memberNo=2170614&navigationType=push","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240523_1095%2Fupload_1716430252319HGjX7.jpg%22&type=f504_292&service=navermain"},"source":{"name":"성안당","service":"POST","image":{"url":"https://s.pstatic.net/post.phinf/MjAyMTA1MTJfMTM0/MDAxNjIwODAyMzQ4NjMw.r8iuNwDsirmdPxNoF6SkvJqEzoVP8J7BXzFinACTjr0g.RuUpVJvLncfaqtqnHmUXKSo3idoKYjHXEHpv7-qeWWcg.PNG/post_1232797342350993410.png?type=f120_120"}},"showLiveBadge":false,"_id":"66097ac1375f36781dc6e2d1"},{"@type":"MATERIAL-PC-FEED","title":"나랏돈으로 비트코인에 올인?! 엘살바도르의 충격적인 반전 근황...","url":"https://post.naver.com/viewer/postView.naver?volumeNo=37833051&memberNo=618343&navigationType=push","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240523_1095%2Fupload_1716430132834QERMW.jpg%22&type=f504_292&service=navermain"},"source":{"name":"다산북스","service":"POST","image":{"url":"https://s.pstatic.net/post.phinf/MjAyNDA0MjVfMTkz/MDAxNzE0MDIxMDM2OTE4.b_kGkioSntBT5UYvrK7524VdLiE0OGRlzd1jmoz87jsg.LupiCYOzYfDsFWGg8RD2N_j5L7YyGvnU8s4HdN4q5aIg.PNG/post_5676330716636061301.png?type=f120_120"}},"showLiveBadge":false,"_id":"66097ac1375f36781dc6e2d2"},{"@type":"MATERIAL-PC-FEED","title":"북으로 간 언어학자 김수경, 트랜스내셔널에서 주체의 늪으로","url":"https://contents.premium.naver.com/historybooks/knowledge/contents/240421112954175fq","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240523_1095%2Fupload_1716430234541NO47r.jpg%22&type=f504_292&service=navermain"},"source":{"name":"역사책의 감동, 역사의 이면","service":"PREMIUM","image":{"url":"https://s.pstatic.net/scs.phinf/MjAyMjAxMDdfMjMw/MDAxNjQxNTA3MDQ2NDE4.lLl5IsZoQupIdvXBWZt4MSXRBP7H6Sj0ehesD6toFaEg.vIorURuLV6pNIFV9ztomJWKUCaBG9nh6Icuh-NXiewIg.JPEG/image%7Cpremium%7Cchannel%7Chistorybooks%7C2022%7C01%7C07%7C1641507046350.jpg"}},"showLiveBadge":false,"_id":"66097ac1375f36781dc6e2d3"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@template":"NONE"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@code":"PC-FEED-LECTURE-TODAY-LECTURE","@template":"HIGHLIGHTED-COLUMNS"},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"기울어진 호기심","url":"https://contents.premium.naver.com/instagram/meditation/contents/240527081421061zd","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fscs.phinf%2FMjAyNDA1MjZfMTky%2FMDAxNzE2NjkzMDE0NTg3.15QKrhbxaiQcivB2N78eCTpMwadkaJAB8n9ykjkdtswg.uKhhl2pxhuoGItOwk8RVWjwIhVm96m8vqHhEbHxGDPAg.PNG%2Fimage.png%22&type=nf308_200&service=navermain"},"desc":"생각노트","source":{"name":"생각노트","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fscs.phinf%2FMjAyMjEwMTBfMTk0%2FMDAxNjY1NDEyNjMyNDky.xVp1tdOBmaTfJ53ix4njpQcv8xbXy_4PL5TKKm8gKD4g.CkuUEDjh1HnZn1iwtvfw5HaaeihPElFuBYXrniGlGb4g.JPEG%2Fimage%257Cpremium%257Cchannel%257Cinstagram%257C2022%257C10%257C10%257C1665412632457.jpg%22&type=nf96_96&service=navermain"}},"labels":[{"type":"paid","text":null}],"showLiveBadge":false,"_id":"6441ca92c499cc07f334c439"},{"@type":"MATERIAL-PC-FEED","title":"목이 댕강 날아가도 의식이 있을까?","url":"https://tv.naver.com/h/51919102","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20240526_277%2Fpu7Ww_1716722696957BUmDL_JPEG%2FKUOXpqKl2n_01.jpg%22&type=nf308_200&service=navermain"},"desc":"지식 채널 미나니","source":{"name":"지식 채널 미나니","image":{"url":"https://s.pstatic.net/dt ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"e4ba39b9-1bcd-11ef-afc6-0997ebe5ddf4","@provider":"lambda","@lastModifiedAt":[2024,5,27,2,7,39,206000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240527 10:50:13","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240527 10:53:36","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240527 10:34:49","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/353.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/353.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240525 07:07:50","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240527 11:05:19","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240523 13:46:46","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240526 15:03:07","_id":null,"@type":"PC-NEWS ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[속보] 정부 \"국민지지에 27년만에 의대증원…개혁에 갈등 따르기 마련\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014709163","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"\"올여름 배추·무 공급 감소…축산물 공급·가격은 안정적\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014709176","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbb"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"서초구, 전국 최초로 대형마트 영업시간 제한 푼다","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014709101","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbc"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"이재명 \"與, 연금개혁 한사코 미루자고 고집…하지 말자는 소리\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014708929","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbd"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"추경호 \"국민적 합의 없이 연금개혁 졸속 추진하면 거센 저항\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014708900","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbe"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"北, 한중일정상회의 직전 정찰위성발사 예고…\"6월4일전에 쏜다\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014708658","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbf"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"\"尹대통령 지지율 30.3%…7주 연속 30% 초반대\"[리얼미터]","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014708650","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dc0"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[전국 레이더] \"아이 납치됐다\" 경찰 80명 출동했는데…도넘은 허위신고","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014708620","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6573c24ecaf3d87b7e4d5269"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"7월부터 연 365회초과 외래진료시 초과 외래진료비 90%부담","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014708618","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"664db652cd8ef9780f996557"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"짙어지는 ' ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"e38aba55-1bcd-11ef-afc6-398fb3ccd583","@provider":"lambda","@lastModifiedAt":[2024,5,27,2,7,37,177000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"eab2b2da-1bcd-11ef-afc6-e594baa760ad","@provider":"lambda","@lastModifiedAt":[2024,5,27,2,7,49,197000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"dff5d3fa-1bcd-11ef-9eb2-77ac6635db1e","@provider":"lambda","@lastModifiedAt":[2024,5,27,2,7,31,170000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"ed161e92-1bcd-11ef-9eb2-9345aa9a0001","@provider":"lambda","@lastModifiedAt":[2024,5,27,2,7,53,206000000]}
# </script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.c56d4f66.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.8c808364.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.6cec4aa5.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.96d3b797.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.fab41863.css" rel="stylesheet"/></link></meta></meta></meta></meta></meta></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div> <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"payload":{"requestId":"381f3fcc4ad9495b9bf322aad6dd1af3","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":99,"adDivId":"ad_timeboard","advertiserDomains":["kr.boucheron.com"],"adDuplicationKeys":["URL:https://kr.boucheron.com"],"ads":[{"encrypted":"Ys9Dp4u0qzaqa5M6SnEJWqakzWdzkEgXKP8Xz6imXqBXIGp6KCPQHkd9QCYwYmcxF_lgYBbULmCg32-4ulGBKHqOCJDQArbbV7gYUsGKSaRBrMGoCk38VsquLDke4SqCdEMMlqsnGnyv9rVFFDEQIPw58iArRkhk3HjYvFcQKCCY3DN_o0XSIl0pHZlXXX-eOwrvE5h2BwygpG80auDrOQTkimVRuoL-p1DUbVrHNo1LPCaL1fMRrgBzj6_c8YqhzCHdeB-0ZlahrhXRmG94zgwAglp7xuvJFhxLNlk1eJUGp1Aj7U-9Tp0QooBZFaDN8jxm0pKrVSBe2VOdtAGblWHXDjuAko-Ke8Flr5P375IHkn2KLm5BX6_pcpkFUWwuED3S0FazWGgq9fbs_GJ4bdjFPmkU7dIWnUet1o448GNhINBoHjFrgTIULyCwx3elF3qit14jIKNHvZah1m8vtqE35RoizDsF9W02swXALDP1XZ9vBwEE2LOo12W918bqiiMIvNY6bHZeLyxrZC8e0_T1gnB6BA0pG7Fp0JtlAbR7m5rnAdxdGBSQtyB6oQo3lbC-ZQh75PvGX9iXMBFIaTC-gK5iHNf2Xw4kquuUNfBnvy6RuB8J2RGuRLJ-wemUNkvCE2c0dDI9NnBUFIDSHaMhIhCZVTlNh5OrQs3N9waVUOPjjCOtGuTYnOfMngkEcvUBJjNj7gCGkkEgLHdHDhJoUpR21HRROd_gFsBFsvE=","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5O3vhO5BAV%2F8En4AryYfI4B0BXbXykVEf6GIF3CHUWCG%2F73dupRUBnuJL1qM2Pf%2FalYjiVlFr%2BhQJW5s5sxhCA%2F2SRxDFw12rfIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8968829\u0026src=7095716\u0026evtcd=BID_WIN\u0026x_ti=1504\u0026rk=OH84WrJ3Lje57fO52XDOMQ\u0026eltts=WbuBoPwgDYyVOvNC3LRRqg%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["kr.boucheron.com"],"cid":"1494548","crid":"2634987","exp":2978,"adm":"%3Cscript%20 ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element=""> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근 검색어</strong> <div class="option"> <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"></ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"> <a class="close _keywordOnOff" href="#">자동저장 끄기</a> </span> <span class="opt_item"><a data-clk="sly.help" href="h ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240527111020',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var o=i&&i.content&&i.content.input&&i.content.input.placeholder;if(o){var s=document.getElementById("query");s&&o&&s.setAttribute("title",o),s&&o&&s.setAttribute("placeholder",o)}}()</script> </body> </html>

# %% [markdown]
# - requests 패키지 사용의 결과

# %%
urlopen("https://www.naver.com/").status
# http 응답 상태 코드 
# - 200 성공
# - 300 리다이렉션 
# - 400 페이지가 없음, 권한이 없는경우 
# - 500 서버 내부의 오류
# Out:
# 200

# %%
urlopen("https://www.galoisoft.com/").status
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:1303, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1302 """Send a complete request to the server."""
# -> 1303 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:1349, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1348     body = _encode(body, 'body')
# -> 1349 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:1298, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1297     raise CannotSendHeader()
# -> 1298 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:1058, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1057 del self._buffer[:]
# -> 1058 self.send(msg)
#    1060 if message_body is not None:
#    1061
#    1062     # create a consistent interface to message_body
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:996, in HTTPConnection.send(self, data)
#     995 if self.auto_open:
# --> 996     self.connect()
#     997 else:
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:1468, in HTTPSConnection.connect(self)
#    1466 "Connect to a host on a given (SSL) port."
# -> 1468 super().connect()
#    1470 if self._tunnel_host:
#
# File ~\anaconda3\envs\week3\Lib\http\client.py:962, in HTTPConnection.connect(self)
#     961 sys.audit("http.client.connect", self, self.host, self.port)
# --> 962 self.sock = self._create_connection(
#     963     (self.host,self.port), self.timeout, self.source_address)
#     964 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~\anaconda3\envs\week3\Lib\socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\envs\week3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 urlopen("https://www.galoisoft.com/").status
#
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\envs\week3\Lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %% [markdown]
# # 웹페이지와 HTML
# - 웹페이지는 HTML(HyperText Markup Language)을 기반으로 생성
# - F12, Ctrl + shift + c, Ctrl + shift + i 를통해 확인 가능
# - 원하는 데이터가 웹페이지의 어느부분에 위치해 있는지 파악이 가능하다.
# ## 1. HTML 태그
# - 기본형
# ```html
# <태그>내용</태그>
# ```
#
# - HTML은 마크로 둘러싸인 언어라는 뜻으로 구조에 대한 정보를 기반으로 작성된 언어
# - 각각의 구성 요소는 마크 역할을 하는 태그로 감싸져 있다.
#     - 웹페이지의 시작과 끝을 의미하는
#     ```html
#     <html></html>
#     ```
#     - 문서의 제목을 의미하는
#     ```html
#     <title></title>
#     ```
#     - 웹에 실제로 표시되는 내용을 의미하는
#     ```html
#     <body></body>
#     ```
#
# ## 2. HTML 태그의 종류
# - ul : unordered list.
# - li : list item.
#     - 목록의 내용이 되는 실질적 태그
#     - [참고](https://www.w3schools.com/html/html_lists.asp)
# - a
#     - 하이퍼링크를 나타내는 태그
#     - [참고](https://www.w3schools.com/tags/tag_a.asp)
#     - <a href="https://www.google.com">google</a>
# - p
#     - paragraph(단락)의 약자, 긴 글 뭉텅이.
#
# - table : 표를 나타내는 태그
#     - [참고](https://www.w3schools.com/html/tryit.asp?filename=tryhtml_table3)

# %% [markdown]
#
# - html 태그
#     - find("태그") - 첫번째 태그만 검색
#     - find_all("태그") - 전체 태그 검색후 list로 반환

# %%
# bs4 객체에서 사용할 수 있는 METHOD
html = urlopen("https://www.naver.com/")
soup = bs(html, "html.parser")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
find_div = soup.find("div", id="u_skip") # div 태그에서 id가 u_skip 인 태그중에 첫번째 태그만을 검색 
print(find_div)
# Out:
# <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>

# %%
# https://www.nate.com 의 soup 객체를 만들고 출력해 보세요
html = urlopen("https://www.nate.com/")
soup = bs(html, "html.parser")
type(soup)
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>네이트</title>
# <link href="/css/common.min.css?v=202404221027_01" rel="stylesheet" type="text/css"/>
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://www.nate.com" rel="canonical"/>
# <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='1';
# 	var iSvcSeqB ='4';
# 	var iSvcSeqC ='2';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verIssue01 		= '202405271101';
# 	var verIssue02 		= '202405271101';
# 	var verIssue03 		= '202405271101';
# 	var verIssue04 		= '202405271101';
# 	var verIssue05 		= '202405271101';
# 	var verIssue06 		= '202405271101';
# 	var verIssue07 		= '202405271101';
#
# 	var verNateTV		= '202405271133';
# 	var verIssueKeyword	= '202405271130';
# 	var verToonNBook	= '202405271127';
#
# 	var verNateQ01		= '202405271128';
# 	var verRanking06	= '202405271103';
#
# 	var verGnbRoll		= '202405271101';
# 	var verNewsBox 		= '202405271131';
# 	var verShopRecomm	= '202405271110';
# 	var verNateQ02		= '202405271104';
#
# 	var verPannTotal		= '202405271129';
# 	var verPannWomanLife	= '202405271129';
# 	var verPannTeens		= '202405271130';
# 	var verPannEnter		= '202405271130';
# 	var verTodayKeyword 	= '202405271133';
# 	var verWorkLife			= '202405271131';
# 	var verKeywordAd		= '202405271117';
# 	var verAdFunFun			= '202405271105';
# 	var verBizSearch 		= '202405241746';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
# 	</script>
# <script src="/js/common/nate_general_v20170627.js?v=202404171352_15" type="text/javascript"></script>
# <script src="/js/common/ac_v5.js?v=20221017_07" type="text/javascript"></script>
# <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript"></script>
# <script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
# </link></head>
# <body>
# <script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# <div id="mainContainer">
# <div class="area_access">
# <h2>네이트 메인페이지 주요 내용 바로가기</h2>
# <ul>
# <li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
# <li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
# <li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="container">
# <div id="header">
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
# <div class="area_ignb" id="divignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# <ul>
# <li><a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# <li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# </ul>
# </div>
# <div class="area_search" role="search">
# <h2>통합검색</h2>
# <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
# <input id="thr" name="thr" type="hidden" value="sbma"/>
# <input id="w" name="w" type="hidden" value="tot"/>
# <fieldset>
# <legend>통합검색 입력</legend>
# <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
# <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" style="ime-mode:active" type="text" value=""/>
# <input class="type_btn" id="acBtn" title="검색" type="submit"/>
# <div id="acDiv" style="display:none;"></div>
# </div>
# </fieldset>
# </form>
# <input id="premiumText" name="premiumText" title="" type="hidden" value="">
# <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
# <input id="statCode" name="statCode" title="" type="hidden" value=""/>
# <div class="search_keyword">
# <dl>
# <dd>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%B0%A8%EB%91%90%EB%A6%AC+%EA%B3%A0%EC%86%8C%EC%A0%84&amp;rtmaxcoll=DNS" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">차두리 고소전</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EB%B3%B4%EC%9C%A1%EA%B5%90%EC%82%AC2%EA%B8%89" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">보육교사2급</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%82%AC%EB%AC%B4%EC%8B%A4%EA%B0%80%EA%B5%AC" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">사무실가구 배치</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%84%B8%EB%B8%90%ED%8B%B4+%ED%98%B8%EC%8B%9C+%EB%85%BC%ED%98%84%EB%8F%99&amp;rtmaxcoll=DNS" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">세븐틴 호시 50억 자택</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%ED%95%98%EC%9D%B4%ED%82%A4+6%EC%9B%94+19%EC%9D%BC&amp;rtmaxcoll=DNS" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">하이키 컴백 확정</a>
# </dd>
# </dl>
# </div>
# <a class="link-ngpt" href="https://m.nate.com/aichat.html" onmousedown="nc('NNC01');" target="_blank">AI챗 바로가기</a>
# </input></div>
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="chat1"><a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">AI챗</a><em class="beta">beta</em></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">툰앤북</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class=""><a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">네이트뷰</a></li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">판포토</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# <li><a href="//m.ssul.nate.com/" onmousedown="nc('NSD46');">썰</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
# </div>
# <div class="area_biz type_alone" id="bizRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">비즈 검색어</a></h3>
# </div>
# <div class="todayBox" id="divTodayKeywordArea" onmouseout="todayKeyword.startTodayKeyword()" onmouseover="todayKeyword.stopTodayKeyword()">
# <div id="divTodayKeyword">
# <a class="keyword" href="https://news.nate.com/?keyword_dtm=2024-05-27 10:49:48&amp;keyword_sq=369574" onmousedown="nc('TOD54');" title="조국 대표 군 사망 사고 비판">조국 대표 군 사망 사고 비판</a>
# </div>
# <div class="kwrd_slide">
# <div class="today_tit">
# <a href="https://news.nate.com/" onmousedown="nc('TOD61');">
# <div class="logoimg">
# <div class="circle step1"></div>
# <div class="circle step2"></div>
# </div>
# <span class="svcname">오늘</span>
# </a>
# </div>
# <button class="btn prev" id="Prev" onclick="todayKeyword.viewPreNext('P')" onmousedown="nc('TOD91');" title="이전" type="button"><span>오늘 키워드 이전 내용</span></button>
# <button class="btn next" id="Next" onclick="todayKeyword.viewPreNext('N')" onmousedown="nc('TOD92');" title="다음" type="button"><span>오늘 키워드 다음 내용</span></button>
# </div>
# </div>
# </div>
# <hr/>
# <div id="content">
# <div class="area_auth" id="UI">
# <h2>회원 로그인 영역</h2>
# <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#                     </script>
# <form action="https://xo.nate.com/LoginAuth.sk" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
# <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
# <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
# <input id="domain" name="domain" type="hidden" value="nate.com"/>
# <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
# <fieldset>
# <legend>회원 로그인</legend>
# <label class="label_id nHide" for="ID">아이디 or @이하 모두 입력</label>
# <input class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
# <label class="label_pw nHide" for="PASSDM">비밀번호</label>
# <label class="label_pw nHide" for="PASSDM" id="lb_passdm">비밀번호</label>
# <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
# <label class="label_pw nHide" for="PASSWD" id="lb_passwd">비밀번호</label>
# <input class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
# <span class="option01"><input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/> <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong id="ipLevelText">ON</strong></a></span>
# <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
# <span class="option02"><a href="javascript:onclick_Find();" title="아이디 찾기">아이디</a> / <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();" title="회원가입"><strong>회원가입</strong></a> </span>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# </fieldset>
# </form>
# <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
# <div class="layer_content"></div>
# </div>
# <div class="overlay_info nHide" id="divNateOn">
# <p>웹 네이트온 로그인은 설치가 필요 없는<br/>가벼운 네이트온이 네이트 로그인 만으로<br/>함께 로그인 되는 편리한 기능입니다.</p>
# <a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">웹 네이트온이란?</a>
# <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# <div class="overlay_info type_saveid nHide">
# <p>개인정보 보호를 위해<br/>개인PC에서만<br/>사용해 주세요. <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&amp;subNodeId=NODE0000000006&amp;keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&amp;pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# </div>
# <hr/>
# <h2>컨텐츠 영역</h2>
# <div class="area_news" id="news_area">
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# <h4 class="menu01 on" id="newstab1"><a href="//news.nate.com/" onclick="newsBox.clickTabLink('tab1_set1');return false;" title="뉴스탭 열기">뉴스</a></h4>
# <h4 class="menu02" id="newstab2"><a href="//sports.news.nate.com/" onclick="newsBox.clickTabLink('tab2_spo');return false;" title="스포츠탭 열기">스포츠</a></h4>
# <h4 class="menu03" id="newstab3"><a href="//news.nate.com/ent/section?mid=e0100;" onclick="newsBox.clickTabLink('tab3_ent');return false;" title="연예탭 열기">연예</a></h4>
# <h4 class="menu04" id="newstab4" style="display:none;"></h4>
# <h4 class="menu05" id="newstab5"><a href="//news.nate.com/rank/?mid=n1000" onclick="newsBox.clickTabLink('tab5_ranking');return false;" title="랭킹뉴스탭 열기">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# <div class="tabCnt">
# <div class="rankBox" id="div_rank_sisa"></div>
# <div class="rankBox" id="div_rank_spo"></div>
# <div class="rankBox" id="div_rank_ent"></div>
# <ul class="type_thumb type02" id="newsImg_ul_1">
# <li id="newsImg0">
# <a href="//news.nate.com/view/20240527n10835" onclick="setTabInfo();ndrclick('MEF01', 'NH_01_01_01-20240527105500');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716774896_399.png" width="168"/></span>
# <span class="txt">유리창에 쾅하고 기절…소쩍새 구조 대작전</span>
# </a>
# </li>
# <li id="newsImg1">
# <a href="//tv.nate.com/clip/5029024" onclick="setTabInfo();ndrclick('MEF02', 'NH_03_01_01-20240527103219');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716773510_226.jpg" width="168"/></span>
# <span class="txt">음주 뺑소니 김호중 팬들의 '살인 예고'... 일그러진 팬심</span>
# </a>
# </li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_1">
# <li id="newsTxt_li_0"><strong><a href="//news.nate.com/hissue/clstList?mid=n0208&amp;isq=11000&amp;n=1056306#cid1056306" onclick="setTabInfo();ndrclick('MEB23', 'NH_01_02_01-20240527104913');" target="_self">사망 훈련병, 완전군장 메고 달리기 했다…훈련규정 위반</a></strong></li>
# <li id="newsTxt_li_1"><a href="//news.nate.com/section?mid=n0500&amp;n=1055527#cid1055527" onclick="setTabInfo();ndrclick('MEB25', 'NH_01_02_09-20240527111406');" target="_self">"내 인생 최악의 15초였다"…여객기 또 난기류 휘말려, 12명 부상</a></li>
# <li id="newsTxt_li_2"><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=9704" onclick="setTabInfo();ndrclick('MEB27', 'NH_01_02_09-20240527094121');" target="_self">"국유지 된 줄 모르고 팔아"…50년 만에 83억 보상받게 된 사연</a></li>
# <li id="newsTxt_li_3"><a href="//sports.news.nate.com/hissue/clstList?mid=s0306&amp;isq=8567&amp;n=689931#cid689931" onclick="setTabInfo();ndrclick('MEB29', 'NH_02_02_02-20240527110448');" target="_self"><span class="sbj">오피셜</span> '김민재-조규성 제외' 김도훈호, 6월 A매치 명단 발표…오세훈, 배준호 등 7명 최초발탁</a></li>
# <li id="newsTxt_li_4"><a href="//news.nate.com/hissue/clstList?mid=e0100&amp;isq=11168&amp;n=1056412#cid1056412" onclick="setTabInfo();ndrclick('MEC61', 'NH_03_02_01-20240527112553');" target="_self">김호중 "증거불충분으로 빠져나가나", 경찰 음주운전 여부 입증 주력</a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_2">
# <li id="newsTxt_li_5"><span class="icon break">속보</span> <strong><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=11104&amp;n=1037333#cid1037333" onclick="setTabInfo();ndrclick('MEB31', 'NH_01_02_02-20240527111735');" target="_self">정부 "국민지지에 27년만에 의대증원…개혁에 갈등 따르기 마련"</a></strong></li>
# <li id="newsTxt_li_6"><a href="//news.nate.com/view/20240527n09182" onclick="setTabInfo();ndrclick('MEB33', 'NH_01_03_01-20240527110808');" target="_self">'얼차려' 사망 12사단, 훈련병들 집단 기침까지…가족들 "건강 파악해 달라" 호소</a></li>
# <li id="newsTxt_li_7"><a href="//news.nate.com/view/20240527n07308" onclick="setTabInfo();ndrclick('MEB35', 'NH_01_03_01-20240527104104');" target="_self">비행기 뜨자 뒷좌석에서 맨발이 '쑤욱'…카메라 켜자 그제서야 '쏘옥'</a></li>
# <li id="newsTxt_li_8"><a href="//sports.news.nate.com/soccer/#cid647355" onclick="setTabInfo();ndrclick('MEB37', 'NH_02_02_06-20240527110834');" target="_self"><span class="sbj">오피셜</span> 감독 공백은 끝났다…영광 재현할 김두현 감독, 전북 제8대 사령탑 선임</a></li>
# <li id="newsTxt_li_9"><a href="//news.nate.com/view/20240527n03108" onclick="setTabInfo();ndrclick('MEC63', 'NH_03_02_02-20240527112553');" target="_self">니콜, 中 걸그룹 서바이벌서 공중요가…카라 박규리·허영지 지원사격</a></li>
# </ul>
# <ul class="type_text nHide" id="newsTxt_ul_3">
# <li id="newsTxt_li_10"></li>
# <li id="newsTxt_li_11"></li>
# <li id="newsTxt_li_12"></li>
# <li id="newsTxt_li_13"></li>
# <li id="newsTxt_li_14"></li>
# </ul>
# <ul class="type_thumb type01" id="newsImg_ul_2">
# <li id="newsImg2">
# <a href="//sports.news.nate.com/abrsoccer/photo?page=1&amp;cid=1056364&amp;fix=1056364" onclick="setTabInfo();ndrclick('MEF03', 'NH_02_01_05-20240527084136');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716765330_920.jpg" width="168"/></span>
# <span class="txt">"메시 누군지도 몰랐다"던 그녀, 세계 女축구 '보스' 된 사연</span>
# </a>
# </li>
# <li id="newsImg3">
# <a href="//news.nate.com/view/20240527n11773" onclick="setTabInfo();ndrclick('MEF04', 'NH_01_04_01-20240527110719');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716775634_196.jpg" width="168"/></span>
# <span class="txt">"새빨간 탁구공처럼 눈알 빠져 돌아온 꿍이"…애견유치원 직원이 '퍽퍽'</span>
# </a>
# </li>
# <li id="newsImg4">
# <a href="//news.nate.com/view/20240527n04404" onclick="setTabInfo();ndrclick('MEF05', 'NH_01_04_02-20240527111603');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716768515_524.jpg" width="168"/></span>
# <span class="txt">게이샤 끝까지 쫓아 '찰칵'…무례한 관광객 폭주에 결국</span>
# </a>
# </li>
# </ul>
# <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
# <div class="plus_content">
# <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304"></iframe>
# <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">뉴스플러스 레이어 닫기</button>
# </div>
# </div>
# </div>
# <div class="bizCnt">
# <div class="isKeyword">
# <h4>실시간 이슈 키워드</h4>
# <ol class="isKeywordList" id="olLiveIssueKeyword">
# <li>
# <span class="num_rank">6</span>
# <a class="ik" href="https://news.nate.com/search?q=민주유공자법 촉구 오체투지" onclick="newsBox.clickSearchKeyword('민주유공자법 촉구 오체투지');return false;" onmousedown="nc('MEH21')">
# <span class="txt_rank">민주유공자법 촉구 오체투지</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">7</span>
# <a class="ik" href="https://news.nate.com/search?q=호중이 형 경찰" onclick="newsBox.clickSearchKeyword('호중이 형 경찰');return false;" onmousedown="nc('MEH22')">
# <span class="txt_rank">호중이 형 경찰</span>
# <span class="fc down"><span class="nHide">하락</span>2</span>
# </a>
# </li>
# <li>
# <span class="num_rank">8</span>
# <a class="ik" href="https://news.nate.com/search?q=조규성도 4도움 시즌" onclick="newsBox.clickSearchKeyword('조규성도 4도움 시즌');return false;" onmousedown="nc('MEH23')">
# <span class="txt_rank">조규성도 4도움 시즌</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">9</span>
# <a class="ik" href="https://news.nate.com/search?q=유재석 이웃 50억" onclick="newsBox.clickSearchKeyword('유재석 이웃 50억');return false;" onmousedown="nc('MEH24')">
# <span class="txt_rank">유재석 이웃 50억</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">10</span>
# <a class="ik" href="https://news.nate.com/search?q=전당대회 5선 서병수" onclick="newsBox.clickSearchKeyword('전당대회 5선 서병수');return false;" onmousedown="nc('MEH25')">
# <span class="txt_rank">전당대회 5선 서병수</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# </ol>
# <form accept-charset="euc-kr" action="https://news.nate.com/search" id="frmKeyword" name="frmKeyword" onsubmit="return false">
# <input id="bizq" name="q" type="hidden" value=""/>
# </form>
# </div>
# <div class="adBox"></div>
# <div class="todayBox" id="divBox">
# <h3>
# <span class="nHide">오늘 &amp; 기타정보</span>
# <strong class="tdate">05.27</strong> 월요일
# 					</h3>
# <h4 class="nHide">날씨</h4>
# <a class="tempinfo" href="#" onmousedown="nc('MEH10');">
# <div>
# <div class="misc">
# <img alt="구름많음" height="42" src="//main2.nateimg.co.kr/img/v7/weather3/52x52_am_03.png" width="42"/>
# </div>
# <div class="temperature">
# <span class="tempdata">23</span>
# </div>
# <div class="rbox">
# <span class="degree">℃</span>
# <span class="local">부산</span>
# </div>
# </div>
# </a>
# <div class="plusinfo">
# <p class="rangeTemp">어제보다 <span>
#
#
#
#
#
# 								1
#
# 						</span></p>
# <a href="http://news.nate.com/weather/airPollution?type=pm10" onmousedown="nc('MEH11');"><p class="dust">미세먼지 <span class="pol1">좋음</span></p></a>
# </div>
# </div>
# </div>
# <dl class="content_recommend">
# <dt id="dtNewsRecomm"><em>뉴스</em></dt>
# <dd id="newsRecommend">
# <a href="//news.nate.com/comment?mid=n1500" onmousedown="nc('MEF32');setTabInfo();">투데이베플</a>
# <a href="//news.nate.com/ent/idol24" onmousedown="nc('MEF33');setTabInfo();">아이돌24시</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7376" onmousedown="nc('MEF34');setTabInfo();">드라마 모아보기</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7377" onmousedown="nc('MEF35');setTabInfo();">예능 모아보기</a>
# </dd>
# </dl>
# </div>
# <div class="nav" id="newsOptBtn">
# <span id="newsMoreArea"><em>1</em> / 6</span>
# <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">자동전환기능 정지</button>
# <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">이전 뉴스 보기</button>
# <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
# <div class="overlay_ticker" id="ticker_lyr" style="display:none">
# <div class="ticker_content">
# <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728"></iframe>
# <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">티커 닫기</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 				//<![CDATA[
# 					loadSpecialBiRolling();
# 				//]]>
# 				</script>
# <!-- tiles:insertAttribute name="NateQ" /-->
# <div class="area_contents" id="divContentsUpper">
# <h3>컨텐츠</h3>
# <div class="menu">
# <h4 class="menu01"><a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" onmousedown="nc('PAN60')" title="Top랭킹">Top랭킹</a></h4>
# <h4 class="menu02"><a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" onmousedown="nc('PAN61')" title="결시친">결시친</a></h4>
# <h4 class="menu03 on"><a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" onmousedown="nc('PAN62')" title="10대톡">10대톡</a></h4>
# <h4 class="menu04"><a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" onmousedown="nc('PAN63')" title="연예톡">연예톡</a></h4>
# <h4 class="menu05"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" onmousedown="nc('PAN64')" title="회사톡">회사톡</a></h4>
# </div>
# <div class="content" id="pannList">
# <ul class="ctList">
# <!-- 썸네일 있는 경우 -->
# <li class="type_thumb">
# <a class="" href="https://pann.nate.com/talk/372609735" onmousedown="nc('PAO21');objPannArea.clickContents(3);">
# <span class="thumb"><img alt="" height="66" src="https://thumb.pann.com/tc_110x70/http://fimg5.pann.com/new/download.jsp?FileID=67747562" width="105"/></span>
# <span class="title">이사람 잡혔는데 몸뚱아리봐봐</span>
# <em class="emph"><span class="nHide">댓글수</span>(250)</em>
# </a>
# </li>
# <!-- 썸네일 있는 경우 -->
# <li class="type_thumb">
# <a class="" href="https://pann.nate.com/talk/372609214" onmousedown="nc('PAO22');objPannArea.clickContents(3);">
# <span class="thumb"><img alt="" height="66" src="https://thumb.pann.com/tc_110x70/http://fimg5.pann.com/new/download.jsp?FileID=67746293" width="105"/></span>
# <span class="title">친구가 나 때문에 인생망했대...</span>
# <em class="emph"><span class="nHide">댓글수</span>(58)</em>
# </a>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(45)</span>
# <a class="link" href="https://pann.nate.com/talk/372608790" onmousedown="nc('PAO23');objPannArea.clickContents(3);">성1범1죄피해자들이 당할당시 입고있던옷</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(43)</span>
# <a class="link" href="https://pann.nate.com/talk/372609675" onmousedown="nc('PAO24');objPannArea.clickContents(3);">침착맨 방금 라방에서 탄원서 언급함</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(129)</span>
# <a class="link" href="https://pann.nate.com/talk/372609880" onmousedown="nc('PAO25');objPannArea.clickContents(3);">존잘 남캐 짤털하자</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(39)</span>
# <a class="link" href="https://pann.nate.com/talk/372608391" onmousedown="nc('PAO26');objPannArea.clickContents(3);">골반수술 전후봐…</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(9)</span>
# <a class="link" href="https://pann.nate.com/talk/372607947" onmousedown="nc('PAO27');objPannArea.clickContents(3);">수퍼노바vs하우스윗 더 취향인거 추반ㄱ</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(57)</span>
# <a class="link" href="https://pann.nate.com/talk/372608591" onmousedown="nc('PAO28');objPannArea.clickContents(3);">남자 키 중요하게 생각하는 애들아 질문있는데</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(21)</span>
# <a class="link" href="https://pann.nate.com/talk/372609178" onmousedown="nc('PAO29');objPannArea.clickContents(3);">카리나 ㄹㅇ여리여리하고 비율 좋다</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(16)</span>
# <a class="link" href="https://pann.nate.com/talk/372610280" onmousedown="nc('PAO30');objPannArea.clickContents(3);">강형욱 해명에 직원들이 재반박한거 봄 ?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(39)</span>
# <a class="link" href="https://pann.nate.com/talk/372611253" onmousedown="nc('PAO31');objPannArea.clickContents(3);">잘생긴남자들 탈탈</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(34)</span>
# <a class="link" href="https://pann.nate.com/talk/372609189" onmousedown="nc('PAO32');objPannArea.clickContents(3);">남자 머글들 이게 가능함?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(17)</span>
# <a class="link" href="https://pann.nate.com/talk/372609766" onmousedown="nc('PAO33');objPannArea.clickContents(3);">서브만 잡는 병 있음</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(8)</span>
# <a class="link" href="https://pann.nate.com/talk/372609590" onmousedown="nc('PAO34');objPannArea.clickContents(3);">원희 과거썰 개웃기다 ㅠ</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(23)</span>
# <a class="link" href="https://pann.nate.com/talk/372610794" onmousedown="nc('PAO35');objPannArea.clickContents(3);">요즘 운동하는 사람들 사이에서 없으면 안된다는거</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(31)</span>
# <a class="link" href="https://pann.nate.com/talk/372610252" onmousedown="nc('PAO36');objPannArea.clickContents(3);">춘향전 솔직히 너무 좀 그렇지않냐</a>
# </div>
# </li>
# </ul>
# </div>
# <!-- nav -->
# <div class="nav">
# <span><a href="//pann.nate.com/" onmousedown="nc('PAN65')">판홈</a> <i>|</i> <em>3</em> / 5</span>
# <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98')" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">이전 컨텐츠 보기</button>
# <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99')" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">다음 컨텐츠 보기</button>
# </div>
# <!-- //nav -->
# </div>
# <div class="area_issue" id="divIssueUp">
# <h3>키워드</h3>
# <div class="menu">
# <div class="keyword_list">
# <div class="list_top">
# <h4 class="menu08"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# <h4 class="menu01"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# <h4 class="menu02"><a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CTG02');">뷰티</a></h4>
# <h4 class="menu03"><a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG03');">푸드</a></h4>
# <h4 class="menu04 on"><a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">만화/웹툰</a></h4>
# <h4 class="menu05"><a href="javascript:issueContents.clickIssueUpCategory(5, 0)" onmousedown="nc('CTG05');">패션</a></h4>
# <h4 class="menu06"><a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CTG06');">라이프</a></h4>
# <h4 class="menu07" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# </div>
# <div class="list_tb" id="divIssueKeyword">
# <h5 class="on"><span class="tbtit">웹툰</span><a href="javascript:issueContents.clickIssueUpToonNBook(0);" onmousedown="nc('CCA57');">툰앤북 인기</a></h5>
# <h5><span class="tbtit">만화</span><a href="javascript:issueContents.clickIssueUpToonNBook(1);" onmousedown="nc('CCA58');">툰앤북NOW</a></h5>
# <h5><span class="tbtit">웹툰</span><a href="javascript:issueContents.clickIssueUpToonNBook(2);" onmousedown="nc('CCA59');">인기 판타지</a></h5>
# <h5><span class="tbtit">만화</span><a href="javascript:issueContents.clickIssueUpToonNBook(3);" onmousedown="nc('CCA60');">행복한 순정</a></h5>
# </div>
# </div>
# </div>
# <div class="content" id="divIssueUpContents">
# <ul>
# <li>
# <a href="https://toonnbook.nate.com/detail/H045781090" onmousedown="nc('CBW01');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202405/17/0038718828/01_0038718828_1610.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">두 번째 남편이 절륜해서 우울하다</strong>
# <span class="author">자라개,지미신,땅사과</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H045879554" onmousedown="nc('CBW02');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202403/28/0038790198/01_0038790198_1609.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">흑룡의 취향</strong>
# <span class="author">닥죽,강규원</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H044937307" onmousedown="nc('CBW03');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202402/05/0038138953/01_0038138953_1348.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">고교정점 Boost</strong>
# <span class="author">쫑,스튜디오 문</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H044631033" onmousedown="nc('CBW04');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202404/11/0037940709/01_0037940709_1144.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">계약직 아내</strong>
# <span class="author">류다현,라미아</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H041231591" onmousedown="nc('CBW05');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data10/SMILE_DATA10/IMG/PWEBTOONS/202310/23/0035870879/01_0035870879_1544.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">꽃은 썩고 너는 남는다</strong>
# <span class="author">연서,폴라</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H045418823" onmousedown="nc('CBW06');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202312/10/0038457250/01_0038457250_1424.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">제물 황녀님</strong>
# <span class="author">정오찬,다흰</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042253104" onmousedown="nc('CBW07');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202405/07/0036486908/01_0036486908_1511.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">아빠 하나 아들 하나</strong>
# <span class="author">공자여설, 열문그룹, jiangjinghaiqi</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H041868007" onmousedown="nc('CBW08');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202403/08/0036257127/01_0036257127_1704.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">너만 모르는 결혼</strong>
# <span class="author">열문그룹</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042624931" onmousedown="nc('CBW09');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202306/27/0036713835/01_0036713835_1701.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">어쩌다 천생연분</strong>
# <span class="author">심해유광</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H041276662" onmousedown="nc('CBW10');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202401/18/0035898858/01_0035898858_0759.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">나를 사랑하지 않는 그대에게</strong>
# <span class="author">연서,빠다</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H040976733" onmousedown="nc('CBW11');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202209/20/0035724404/01_0035724404_1626.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">톱스타의 계약 결혼</strong>
# <span class="author">DAZUI,동청cutie </span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042169184" onmousedown="nc('CBW12');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202305/08/0036433365/01_0036433365_1553.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">계약 남편에게 끌리는 이유</strong>
# <span class="author">장미 스튜디오,열문그룹</span>
# </span>
# </a>
# <cite>툰앤북 <em>웹툰</em></cite>
# </li>
# </ul>
# </div>
# <div class="content type_err nHide" id="emergencyLayer">
# <h4 class="">쇼핑탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br><strong>쇼핑탭은 지금 점검</strong> 중입니다.</br></br></p>
# <a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="overlay_ally" style="display:none;"></div>
# <div class="movplay" id="movieSec">
# <div class="issuemov">
# <div id="divPlayer"></div>
# <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">광고 자세히보기</a>
# <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">동영상 플레이 레이어 닫기</button>
# </div>
# <span class="shadow"></span>
# </div>
# <div class="content type_err tbe nHide" id="divToonNBookErrLayer">
# <h4 class="">만화/웹툰탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>만화/웹툰탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://toonnbook.nate.com">네이트 툰앤북으로 바로가기</a>
# </div>
# </div>
# <div class="area_best">
# <h3>베스트 컨텐츠</h3>
# <h4>당신이 놓친 오늘의<br/>추천 콘텐츠</h4>
# <ul>
# <li>
# <a href="https://view.nate.com/enter/view/164386/" onmousedown="nc('RCM01');" title="결혼을 앞두고 취소 기자회견 준비도?">
# <span class="thumb">
# <img alt="결혼을 앞두고 취소 기자회견 준비도?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716181315999.jpg" width="94"/></span>
# <span class="title">
# 						결혼을 앞두고 취소 기자회견 준비도?
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20240520n01790" onmousedown="nc('RCM02');" title="군살 하나도 없어서 다이어트 대성공?">
# <span class="thumb">
# <img alt="군살 하나도 없어서 다이어트 대성공?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716181431998.jpg" width="94"/></span>
# <span class="title">
# 						군살 하나도 없어서 다이어트 대성공?
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20240517n02920" onmousedown="nc('RCM03');" title="건강한 습관 들이는 '갓생' 실천 식단">
# <span class="thumb">
# <img alt="건강한 습관 들이는 '갓생' 실천 식단" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716180000416.jpg" width="94"/></span>
# <span class="title">
# 						건강한 습관 들이는 '갓생' 실천 식단
# 						</span>
# <cite>
# 						 푸드
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20240509n43731" onmousedown="nc('RCM04');" title="풋풋한 느낌 그대로 '10대 임솔' 모습">
# <span class="thumb">
# <img alt="풋풋한 느낌 그대로 '10대 임솔' 모습" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716171088382.jpg" width="94"/></span>
# <span class="title">
# 						풋풋한 느낌 그대로 '10대 임솔' 모습
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# </ul>
# </div>
# <div class="area_ranking">
# <h3>랭킹</h3>
# <div class="menu">
# <h4 class="menu01">Biz 추천검색어</h4>
# </div>
# <div class="content" onmouseout="nateRanking.startRolling()" onmouseover="nateRanking.stopRolling()">
# <ul class="type_thumb">
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=사무용가구	" onmousedown="nc('RKM41')" title="사무용가구 할인	">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1705623514_509.jpg"/></span>
# <span class="text">사무용가구 할인	</span>
# <span class="desc">인기 사무용 책상, 의자 </span>
# </a>
# </li>
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=목조주택" onmousedown="nc('RKM42')" title="단아한 아름다움 목조주택">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1715928599_6930.jpg"/></span>
# <span class="text">단아한 아름다움 목조주택</span>
# <span class="desc">목조주택 사진, 시공 가격</span>
# </a>
# </li>
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=단독주택" onmousedown="nc('RKM43')" title="감각적인 단독주택 인테리어">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1715928599_1517.jpg"/></span>
# <span class="text">감각적인 단독주택 인테리어</span>
# <span class="desc">인테리어별 설계비용 보기</span>
# </a>
# </li>
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=루테인지아잔틴" onmousedown="nc('RKM44')" title="눈건강 루테인">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1715928598_4867.jpg"/></span>
# <span class="text">눈건강 루테인</span>
# <span class="desc">눈 영양제 선택 비교분석</span>
# </a>
# </li>
# <li class="commercial">
# <a href="https://dbinsure.co.kr/new/driver?JEHUSA_CD=C5204&amp;utm_medium=cpc&amp;utm_source=nate_pc&amp;utm_campaign=biz&amp;utm_content=newdriver&amp;utm_term=%EC%9A%B4%EC%A0%84%EC%9E%90%EB%B3%B4%ED%97%98" onmousedown="nc('RKM45')" target="_blank" title="DB손해보험 운전자보험">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1709813338_4607.jpg"/></span>
# <span class="text">DB손해보험 운전자보험</span>
# <span class="desc">보험료 간편 계산해보세요</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="paging_slide">
# <span class="num_count_1"><em>2</em> / 2</span>
# <button class="btn prev" onclick="nateRanking.clickRankingBtn('P');" onmousedown="nc('RKN98');" title="이전" type="button">이전</button>
# <button class="btn next" onclick="nateRanking.clickRankingBtn('N');" onmousedown="nc('RKN99');" title="다음" type="button">다음</button>
# </div>
# </div>
# <hr/>
# <h2>쇼핑&amp; 광고 영역</h2>
# <div class="area_shopping" id="shopping" style="display:none">
# <h3>쇼핑</h3>
# <div class="mall1shop" id="shopitemMall">
# <h3 class="tab" id="mall1Title"><a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# <div class="shopmall" id="mall1Box"></div>
# <h3 class="tab" id="mall2Title"><a class="link" href="#" onmousedown="ndrclick2('NFC01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall2Box"></div>
# <h3 class="tab" id="mall3Title"><a class="link" href="#" onmousedown="ndrclick2('NFE01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall3Box"></div>
# <h3 class="tab" id="mall4Title"><a class="link" href="#" onmousedown="ndrclick2('NFG01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall4Box"></div>
# <div id="relShopping">
# <strong class="nHide">쇼핑 관련 리스트</strong>
# <div class="paging_slide">
# <button class="btn prev" id="shoppingPrev" onmousedown="ndrclick2('NFZ01')" title="이전" type="button">쇼핑 이전 내용</button>
# <button class="btn next" id="shoppingNext" onmousedown="ndrclick2('NFZ02')" title="다음" type="button">쇼핑 다음 내용</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
# </script>
# </div>
# <div class="area_shopping type_err" id="shopping_err" style="display:none">
# <h4 class="">쇼핑박스 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br/><strong>쇼핑박스는 지금 점검</strong> 중입니다.</br></p>
# <a href="http://shopping.nate.com">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="area_shopping_today">
# <!-- tiles:insertAttribute name="shopRecommendation" /-->
# </div>
# <div class="area_quick" id="divQuickMenu">
# <h3>퀵링크</h3>
# <div class="area_sktad01"></div>
# <ul>
# <li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
# <li>
# <a href="https://tv.nate.com/" onmousedown="nc('RAB25');" title="네이트TV 서비스 가기">네이트TV</a>
# </li>
# <li>
# <a href="https://m.ssul.nate.com/" onmousedown="nc('RAB26');" title="네이트썰 서비스 가기">네이트썰</a>
# </li>
# <li>
# <a href="https://mobile.nate.com/decorate/mvno/top" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">컬러링</a>
# </li>
# <li>
# <a href="http://editor.nate.com/" onmousedown="nc('RAB23');" title="이슈UP추천 서비스 가기">이슈UP추천</a>
# </li>
# <li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# </ul>
# </div>
# <div class="area_mallAd" id="divMallMenu"></div>
# </div>
# <hr/>
# <div id="footer">
# <h2>푸터 영역</h2>
# <div class="notice">
# <h3><a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">공지사항</a></h3>
# <a href="https://helpdesk.nate.com/web/notice/main-detail?id=8809" onmousedown="nc('NFT02');">네이트메일 모바일웹 UI 개편 안내</a>
# </div>
# <dl>
# <dt>네이트 공용 푸터</dt>
# <dd>
# <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# <a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# <a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# <a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# <span class="copyright">© <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT41');" target="_blank"><strong><span class="sk">SK</span> Communications.</strong></a></span>
# </dd>
# </dl>
# <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# <hr/>
# <div id="adContainer">
# <h2>광고 영역</h2>
# <div class="area_ad01" id="ad_layer1"></div>
# <div class="area_ad02" id="ad_layer2">
# </div>
# <div class="area_adual">
# <div class="area_ad03">
# </div>
# <div class="area_ad04">
# </div>
# </div>
# <div class="area_ad05 nHide" id="leftAd05Cj">
# <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/></a>
# </div>
# <div class="area_ad06"></div>
# <div class="area_sktad02"></div>
# <div class="area_ad09">
# <!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
# </div>
# <div class="area_ad10">
# <a href="https://news.nate.com/ent/idol24/" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img alt=" 아이돌24" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716514417040.png" width="332"/></a>
# </div>
# <div id="ad_layer3"></div>
# <div id="ad_layer4" style="display:none;"></div>
# </div>
# </div>
# <div id="cbContainer">
# <div class="area_ad08" id="cbLayer" style="display: none">
# <span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">NATE를 시작페이지로</a>
# </div>
# </div>
# </div>
# <div class="setting_moblie" id="plus_footer" style="display: none"></div>
# <span id="layerTemp"></span>
# <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
# <!--natemain-->
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script></body></html>

# %%
html.status
# Out:
# 200

# %%
html.

# %%
# request.get 사용
# https://www.nate.com 의 soup 객체를 만들고 출력해 보세요
import requests
html = requests.get("https://www.nate.com/")
soup = bs(html.text, "html.parser")
type(soup)
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>네이트</title>
# <link href="/css/common.min.css?v=202404221027_01" rel="stylesheet" type="text/css"/>
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://www.nate.com" rel="canonical"/>
# <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='1';
# 	var iSvcSeqB ='1';
# 	var iSvcSeqC ='1';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verIssue01 		= '202405271101';
# 	var verIssue02 		= '202405271101';
# 	var verIssue03 		= '202405271101';
# 	var verIssue04 		= '202405271101';
# 	var verIssue05 		= '202405271101';
# 	var verIssue06 		= '202405271101';
# 	var verIssue07 		= '202405271101';
#
# 	var verNateTV		= '202405271133';
# 	var verIssueKeyword	= '202405271135';
# 	var verToonNBook	= '202405271127';
#
# 	var verNateQ01		= '202405271128';
# 	var verRanking06	= '202405271103';
#
# 	var verGnbRoll		= '202405271101';
# 	var verNewsBox 		= '202405271131';
# 	var verShopRecomm	= '202405271110';
# 	var verNateQ02		= '202405271104';
#
# 	var verPannTotal		= '202405271129';
# 	var verPannWomanLife	= '202405271129';
# 	var verPannTeens		= '202405271130';
# 	var verPannEnter		= '202405271130';
# 	var verTodayKeyword 	= '202405271133';
# 	var verWorkLife			= '202405271131';
# 	var verKeywordAd		= '202405271117';
# 	var verAdFunFun			= '202405271105';
# 	var verBizSearch 		= '202405241746';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
# 	</script>
# <script src="/js/common/nate_general_v20170627.js?v=202404171352_15" type="text/javascript"></script>
# <script src="/js/common/ac_v5.js?v=20221017_07" type="text/javascript"></script>
# <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript"></script>
# <script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
# </link></head>
# <body>
# <script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# <div id="mainContainer">
# <div class="area_access">
# <h2>네이트 메인페이지 주요 내용 바로가기</h2>
# <ul>
# <li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
# <li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
# <li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="container">
# <div id="header">
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
# <div class="area_ignb" id="divignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# <ul>
# <li><a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# <li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# </ul>
# </div>
# <div class="area_search" role="search">
# <h2>통합검색</h2>
# <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
# <input id="thr" name="thr" type="hidden" value="sbma"/>
# <input id="w" name="w" type="hidden" value="tot"/>
# <fieldset>
# <legend>통합검색 입력</legend>
# <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
# <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" style="ime-mode:active" type="text" value=""/>
# <input class="type_btn" id="acBtn" title="검색" type="submit"/>
# <div id="acDiv" style="display:none;"></div>
# </div>
# </fieldset>
# </form>
# <input id="premiumText" name="premiumText" title="" type="hidden" value="">
# <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
# <input id="statCode" name="statCode" title="" type="hidden" value=""/>
# <div class="search_keyword">
# <dl>
# <dd>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%B0%A8%EB%91%90%EB%A6%AC+%EA%B3%A0%EC%86%8C%EC%A0%84&amp;rtmaxcoll=DNS" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">차두리 고소전</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EB%B3%B4%EC%9C%A1%EA%B5%90%EC%82%AC2%EA%B8%89" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">보육교사2급</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%82%AC%EB%AC%B4%EC%8B%A4%EA%B0%80%EA%B5%AC" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">사무실가구 배치</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%84%B8%EB%B8%90%ED%8B%B4+%ED%98%B8%EC%8B%9C+%EB%85%BC%ED%98%84%EB%8F%99&amp;rtmaxcoll=DNS" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">세븐틴 호시 50억 자택</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%ED%95%98%EC%9D%B4%ED%82%A4+6%EC%9B%94+19%EC%9D%BC&amp;rtmaxcoll=DNS" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">하이키 컴백 확정</a>
# </dd>
# </dl>
# </div>
# <a class="link-ngpt" href="https://m.nate.com/aichat.html" onmousedown="nc('NNC01');" target="_blank">AI챗 바로가기</a>
# </input></div>
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="chat1"><a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">AI챗</a><em class="beta">beta</em></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">툰앤북</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class=""><a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">네이트뷰</a></li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">판포토</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# <li><a href="//m.ssul.nate.com/" onmousedown="nc('NSD46');">썰</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
# </div>
# <div class="area_biz type_alone" id="bizRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">비즈 검색어</a></h3>
# </div>
# <div class="todayBox" id="divTodayKeywordArea" onmouseout="todayKeyword.startTodayKeyword()" onmouseover="todayKeyword.stopTodayKeyword()">
# <div id="divTodayKeyword">
# <a class="keyword" href="https://news.nate.com/?keyword_dtm=2024-05-27 10:49:48&amp;keyword_sq=369570" onmousedown="nc('TOD51');" title="차두리 내연 문제로 고소전">차두리 내연 문제로 고소전</a>
# </div>
# <div class="kwrd_slide">
# <div class="today_tit">
# <a href="https://news.nate.com/" onmousedown="nc('TOD61');">
# <div class="logoimg">
# <div class="circle step1"></div>
# <div class="circle step2"></div>
# </div>
# <span class="svcname">오늘</span>
# </a>
# </div>
# <button class="btn prev" id="Prev" onclick="todayKeyword.viewPreNext('P')" onmousedown="nc('TOD91');" title="이전" type="button"><span>오늘 키워드 이전 내용</span></button>
# <button class="btn next" id="Next" onclick="todayKeyword.viewPreNext('N')" onmousedown="nc('TOD92');" title="다음" type="button"><span>오늘 키워드 다음 내용</span></button>
# </div>
# </div>
# </div>
# <hr/>
# <div id="content">
# <div class="area_auth" id="UI">
# <h2>회원 로그인 영역</h2>
# <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#                     </script>
# <form action="https://xo.nate.com/LoginAuth.sk" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
# <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
# <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
# <input id="domain" name="domain" type="hidden" value="nate.com"/>
# <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
# <fieldset>
# <legend>회원 로그인</legend>
# <label class="label_id nHide" for="ID">아이디 or @이하 모두 입력</label>
# <input class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
# <label class="label_pw nHide" for="PASSDM">비밀번호</label>
# <label class="label_pw nHide" for="PASSDM" id="lb_passdm">비밀번호</label>
# <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
# <label class="label_pw nHide" for="PASSWD" id="lb_passwd">비밀번호</label>
# <input class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
# <span class="option01"><input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/> <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong id="ipLevelText">ON</strong></a></span>
# <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
# <span class="option02"><a href="javascript:onclick_Find();" title="아이디 찾기">아이디</a> / <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();" title="회원가입"><strong>회원가입</strong></a> </span>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# </fieldset>
# </form>
# <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
# <div class="layer_content"></div>
# </div>
# <div class="overlay_info nHide" id="divNateOn">
# <p>웹 네이트온 로그인은 설치가 필요 없는<br/>가벼운 네이트온이 네이트 로그인 만으로<br/>함께 로그인 되는 편리한 기능입니다.</p>
# <a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">웹 네이트온이란?</a>
# <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# <div class="overlay_info type_saveid nHide">
# <p>개인정보 보호를 위해<br/>개인PC에서만<br/>사용해 주세요. <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&amp;subNodeId=NODE0000000006&amp;keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&amp;pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# </div>
# <hr/>
# <h2>컨텐츠 영역</h2>
# <div class="area_news" id="news_area">
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# <h4 class="menu01 on" id="newstab1"><a href="//news.nate.com/" onclick="newsBox.clickTabLink('tab1_set1');return false;" title="뉴스탭 열기">뉴스</a></h4>
# <h4 class="menu02" id="newstab2"><a href="//sports.news.nate.com/" onclick="newsBox.clickTabLink('tab2_spo');return false;" title="스포츠탭 열기">스포츠</a></h4>
# <h4 class="menu03" id="newstab3"><a href="//news.nate.com/ent/section?mid=e0100;" onclick="newsBox.clickTabLink('tab3_ent');return false;" title="연예탭 열기">연예</a></h4>
# <h4 class="menu04" id="newstab4" style="display:none;"></h4>
# <h4 class="menu05" id="newstab5"><a href="//news.nate.com/rank/?mid=n1000" onclick="newsBox.clickTabLink('tab5_ranking');return false;" title="랭킹뉴스탭 열기">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# <div class="tabCnt">
# <div class="rankBox" id="div_rank_sisa"></div>
# <div class="rankBox" id="div_rank_spo"></div>
# <div class="rankBox" id="div_rank_ent"></div>
# <ul class="type_thumb type02" id="newsImg_ul_1">
# <li id="newsImg0">
# <a href="//news.nate.com/view/20240527n10835" onclick="setTabInfo();ndrclick('MEF01', 'NH_01_01_01-20240527105500');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716774896_399.png" width="168"/></span>
# <span class="txt">유리창에 쾅하고 기절…소쩍새 구조 대작전</span>
# </a>
# </li>
# <li id="newsImg1">
# <a href="//tv.nate.com/clip/5029024" onclick="setTabInfo();ndrclick('MEF02', 'NH_03_01_01-20240527103219');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716773510_226.jpg" width="168"/></span>
# <span class="txt">음주 뺑소니 김호중 팬들의 '살인 예고'... 일그러진 팬심</span>
# </a>
# </li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_1">
# <li id="newsTxt_li_0"><strong><a href="//news.nate.com/hissue/clstList?mid=n0208&amp;isq=11000&amp;n=1056306#cid1056306" onclick="setTabInfo();ndrclick('MEB23', 'NH_01_02_01-20240527104913');" target="_self">사망 훈련병, 완전군장 메고 달리기 했다…훈련규정 위반</a></strong></li>
# <li id="newsTxt_li_1"><a href="//news.nate.com/section?mid=n0500&amp;n=1055527#cid1055527" onclick="setTabInfo();ndrclick('MEB25', 'NH_01_02_09-20240527111406');" target="_self">"내 인생 최악의 15초였다"…여객기 또 난기류 휘말려, 12명 부상</a></li>
# <li id="newsTxt_li_2"><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=9704" onclick="setTabInfo();ndrclick('MEB27', 'NH_01_02_09-20240527094121');" target="_self">"국유지 된 줄 모르고 팔아"…50년 만에 83억 보상받게 된 사연</a></li>
# <li id="newsTxt_li_3"><a href="//sports.news.nate.com/hissue/clstList?mid=s0306&amp;isq=8567&amp;n=689931#cid689931" onclick="setTabInfo();ndrclick('MEB29', 'NH_02_02_02-20240527110448');" target="_self"><span class="sbj">오피셜</span> '김민재-조규성 제외' 김도훈호, 6월 A매치 명단 발표…오세훈, 배준호 등 7명 최초발탁</a></li>
# <li id="newsTxt_li_4"><a href="//news.nate.com/hissue/clstList?mid=e0100&amp;isq=11168&amp;n=1056412#cid1056412" onclick="setTabInfo();ndrclick('MEC61', 'NH_03_02_01-20240527112553');" target="_self">김호중 "증거불충분으로 빠져나가나", 경찰 음주운전 여부 입증 주력</a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_2">
# <li id="newsTxt_li_5"><span class="icon break">속보</span> <strong><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=11104&amp;n=1037333#cid1037333" onclick="setTabInfo();ndrclick('MEB31', 'NH_01_02_02-20240527111735');" target="_self">정부 "국민지지에 27년만에 의대증원…개혁에 갈등 따르기 마련"</a></strong></li>
# <li id="newsTxt_li_6"><a href="//news.nate.com/view/20240527n09182" onclick="setTabInfo();ndrclick('MEB33', 'NH_01_03_01-20240527110808');" target="_self">'얼차려' 사망 12사단, 훈련병들 집단 기침까지…가족들 "건강 파악해 달라" 호소</a></li>
# <li id="newsTxt_li_7"><a href="//news.nate.com/view/20240527n07308" onclick="setTabInfo();ndrclick('MEB35', 'NH_01_03_01-20240527104104');" target="_self">비행기 뜨자 뒷좌석에서 맨발이 '쑤욱'…카메라 켜자 그제서야 '쏘옥'</a></li>
# <li id="newsTxt_li_8"><a href="//sports.news.nate.com/soccer/#cid647355" onclick="setTabInfo();ndrclick('MEB37', 'NH_02_02_06-20240527110834');" target="_self"><span class="sbj">오피셜</span> 감독 공백은 끝났다…영광 재현할 김두현 감독, 전북 제8대 사령탑 선임</a></li>
# <li id="newsTxt_li_9"><a href="//news.nate.com/view/20240527n03108" onclick="setTabInfo();ndrclick('MEC63', 'NH_03_02_02-20240527112553');" target="_self">니콜, 中 걸그룹 서바이벌서 공중요가…카라 박규리·허영지 지원사격</a></li>
# </ul>
# <ul class="type_text nHide" id="newsTxt_ul_3">
# <li id="newsTxt_li_10"></li>
# <li id="newsTxt_li_11"></li>
# <li id="newsTxt_li_12"></li>
# <li id="newsTxt_li_13"></li>
# <li id="newsTxt_li_14"></li>
# </ul>
# <ul class="type_thumb type01" id="newsImg_ul_2">
# <li id="newsImg2">
# <a href="//sports.news.nate.com/abrsoccer/photo?page=1&amp;cid=1056364&amp;fix=1056364" onclick="setTabInfo();ndrclick('MEF03', 'NH_02_01_05-20240527084136');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716765330_920.jpg" width="168"/></span>
# <span class="txt">"메시 누군지도 몰랐다"던 그녀, 세계 女축구 '보스' 된 사연</span>
# </a>
# </li>
# <li id="newsImg3">
# <a href="//news.nate.com/view/20240527n11773" onclick="setTabInfo();ndrclick('MEF04', 'NH_01_04_01-20240527110719');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716775634_196.jpg" width="168"/></span>
# <span class="txt">"새빨간 탁구공처럼 눈알 빠져 돌아온 꿍이"…애견유치원 직원이 '퍽퍽'</span>
# </a>
# </li>
# <li id="newsImg4">
# <a href="//news.nate.com/view/20240527n04404" onclick="setTabInfo();ndrclick('MEF05', 'NH_01_04_02-20240527111603');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2024/05/27/1716768515_524.jpg" width="168"/></span>
# <span class="txt">게이샤 끝까지 쫓아 '찰칵'…무례한 관광객 폭주에 결국</span>
# </a>
# </li>
# </ul>
# <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
# <div class="plus_content">
# <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304"></iframe>
# <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">뉴스플러스 레이어 닫기</button>
# </div>
# </div>
# </div>
# <div class="bizCnt">
# <div class="isKeyword">
# <h4>실시간 이슈 키워드</h4>
# <ol class="isKeywordList" id="olLiveIssueKeyword">
# <li>
# <span class="num_rank">1</span>
# <a class="ik" href="https://news.nate.com/search?q=차두리 이혼" onclick="newsBox.clickSearchKeyword('차두리 이혼');return false;" onmousedown="nc('MEH01')">
# <span class="txt_rank">차두리 이혼</span>
# <span class="fc same"><span class="nHide">동일</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">2</span>
# <a class="ik" href="https://news.nate.com/search?q=이재명 연금개혁" onclick="newsBox.clickSearchKeyword('이재명 연금개혁');return false;" onmousedown="nc('MEH02')">
# <span class="txt_rank">이재명 연금개혁</span>
# <span class="fc same"><span class="nHide">동일</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">3</span>
# <a class="ik" href="https://news.nate.com/search?q=우주항공청 개청" onclick="newsBox.clickSearchKeyword('우주항공청 개청');return false;" onmousedown="nc('MEH03')">
# <span class="txt_rank">우주항공청 개청</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">4</span>
# <a class="ik" href="https://news.nate.com/search?q=KB금융 제고 계획" onclick="newsBox.clickSearchKeyword('KB금융 제고 계획');return false;" onmousedown="nc('MEH04')">
# <span class="txt_rank">KB금융 제고 계획</span>
# <span class="fc same"><span class="nHide">동일</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">5</span>
# <a class="ik" href="https://news.nate.com/search?q=군인권센터 훈련병 사망" onclick="newsBox.clickSearchKeyword('군인권센터 훈련병 사망');return false;" onmousedown="nc('MEH05')">
# <span class="txt_rank">군인권센터 훈련병 사망</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# </ol>
# <form accept-charset="euc-kr" action="https://news.nate.com/search" id="frmKeyword" name="frmKeyword" onsubmit="return false">
# <input id="bizq" name="q" type="hidden" value=""/>
# </form>
# </div>
# <div class="adBox"></div>
# <div class="todayBox" id="divBox">
# <h3>
# <span class="nHide">오늘 &amp; 기타정보</span>
# <strong class="tdate">05.27</strong> 월요일
# 					</h3>
# <h4 class="nHide">날씨</h4>
# <a class="tempinfo" href="#" onmousedown="nc('MEH10');">
# <div>
# <div class="misc">
# <img alt="구름조금" height="42" src="//main2.nateimg.co.kr/img/v7/weather3/52x52_am_02.png" width="42"/>
# </div>
# <div class="temperature">
# <span class="tempdata">20</span>
# </div>
# <div class="rbox">
# <span class="degree">℃</span>
# <span class="local">서울</span>
# </div>
# </div>
# </a>
# <div class="plusinfo">
# <p class="rangeTemp">어제보다 <span>
#
#
#
#
# 								-4℃ 낮음
#
#
# 						</span></p>
# <a href="http://news.nate.com/weather/airPollution?type=pm10" onmousedown="nc('MEH11');"><p class="dust">미세먼지 <span class="pol2">보통</span></p></a>
# </div>
# </div>
# </div>
# <dl class="content_recommend">
# <dt id="dtNewsRecomm"><em>뉴스</em></dt>
# <dd id="newsRecommend">
# <a href="//news.nate.com/comment?mid=n1500" onmousedown="nc('MEF32');setTabInfo();">투데이베플</a>
# <a href="//news.nate.com/ent/idol24" onmousedown="nc('MEF33');setTabInfo();">아이돌24시</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7376" onmousedown="nc('MEF34');setTabInfo();">드라마 모아보기</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7377" onmousedown="nc('MEF35');setTabInfo();">예능 모아보기</a>
# </dd>
# </dl>
# </div>
# <div class="nav" id="newsOptBtn">
# <span id="newsMoreArea"><em>1</em> / 6</span>
# <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">자동전환기능 정지</button>
# <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">이전 뉴스 보기</button>
# <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
# <div class="overlay_ticker" id="ticker_lyr" style="display:none">
# <div class="ticker_content">
# <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728"></iframe>
# <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">티커 닫기</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 				//<![CDATA[
# 					loadSpecialBiRolling();
# 				//]]>
# 				</script>
# <!-- tiles:insertAttribute name="NateQ" /-->
# <div class="area_contents" id="divContentsUpper">
# <h3>컨텐츠</h3>
# <div class="menu">
# <h4 class="menu01 on"><a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" onmousedown="nc('PAN60')" title="Top랭킹">Top랭킹</a></h4>
# <h4 class="menu02"><a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" onmousedown="nc('PAN61')" title="결시친">결시친</a></h4>
# <h4 class="menu03"><a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" onmousedown="nc('PAN62')" title="10대톡">10대톡</a></h4>
# <h4 class="menu04"><a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" onmousedown="nc('PAN63')" title="연예톡">연예톡</a></h4>
# <h4 class="menu05"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" onmousedown="nc('PAN64')" title="회사톡">회사톡</a></h4>
# </div>
# <div class="content" id="pannList">
# <ol class="rank">
# <li>
# <div class="list_box">
# <span class="num_rank">1</span>
# <span class="emph"><span class="nHide">댓글수</span>(250)</span>
# <a class="link" href="https://pann.nate.com/talk/372609735" onmousedown="nc('PAO80');objPannArea.clickContents(0);">이사람 잡혔는데 몸뚱아리봐봐</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">2</span>
# <span class="emph"><span class="nHide">댓글수</span>(202)</span>
# <a class="link" href="https://pann.nate.com/talk/372609494" onmousedown="nc('PAO81');objPannArea.clickContents(0);">르세라핌 사쿠라 이거 진짜야?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">3</span>
# <span class="emph"><span class="nHide">댓글수</span>(123)</span>
# <a class="link" href="https://pann.nate.com/talk/372607934" onmousedown="nc('PAO82');objPannArea.clickContents(0);">오해원 개그캐로만 소비되는 거</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">4</span>
# <span class="emph"><span class="nHide">댓글수</span>(98)</span>
# <a class="link" href="https://pann.nate.com/talk/372610016" onmousedown="nc('PAO83');objPannArea.clickContents(0);">침착맨 깡다구 미친듯</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">5</span>
# <span class="emph"><span class="nHide">댓글수</span>(85)</span>
# <a class="link" href="https://pann.nate.com/talk/372611259" onmousedown="nc('PAO84');objPannArea.clickContents(0);">친정엄마랑만 여행다니면 차별인가요?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">6</span>
# <span class="emph"><span class="nHide">댓글수</span>(58)</span>
# <a class="link" href="https://pann.nate.com/talk/372609214" onmousedown="nc('PAO85');objPannArea.clickContents(0);">친구가 나 때문에 인생망했대...</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">7</span>
# <span class="emph"><span class="nHide">댓글수</span>(92)</span>
# <a class="link" href="https://pann.nate.com/talk/372608438" onmousedown="nc('PAO86');objPannArea.clickContents(0);">지금 민희진 사태 일어난 뒤부터 판 이상함</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">8</span>
# <span class="emph"><span class="nHide">댓글수</span>(51)</span>
# <a class="link" href="https://pann.nate.com/talk/372608903" onmousedown="nc('PAO87');objPannArea.clickContents(0);">오늘 인가 엔딩무대 윈터</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">9</span>
# <span class="emph"><span class="nHide">댓글수</span>(45)</span>
# <a class="link" href="https://pann.nate.com/talk/372608790" onmousedown="nc('PAO88');objPannArea.clickContents(0);">성1범1죄피해자들이 당할당시 입고있던옷</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">10</span>
# <span class="emph"><span class="nHide">댓글수</span>(76)</span>
# <a class="link" href="https://pann.nate.com/talk/372610330" onmousedown="nc('PAO89');objPannArea.clickContents(0);">제가 알콜중독인가요?</a>
# </div>
# </li>
# </ol>
# <ol class="rank" start="11">
# <li>
# <div class="list_box">
# <span class="num_rank">11</span>
# <span class="emph"><span class="nHide">댓글수</span>(43)</span>
# <a class="link" href="https://pann.nate.com/talk/372609675" onmousedown="nc('PAO90');objPannArea.clickContents(0);">침착맨 방금 라방에서 탄원서 언급함</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">12</span>
# <span class="emph"><span class="nHide">댓글수</span>(45)</span>
# <a class="link" href="https://pann.nate.com/talk/372610177" onmousedown="nc('PAO91');objPannArea.clickContents(0);">에스파랑 뉴진스</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">13</span>
# <span class="emph"><span class="nHide">댓글수</span>(68)</span>
# <a class="link" href="https://pann.nate.com/talk/372611190" onmousedown="nc('PAO92');objPannArea.clickContents(0);">뉴진스 코디 누구냐</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">14</span>
# <span class="emph"><span class="nHide">댓글수</span>(160)</span>
# <a class="link" href="https://pann.nate.com/talk/372610466" onmousedown="nc('PAO93');objPannArea.clickContents(0);">라이즈 유사 제일 심한 멤버 ㄴㄱ임?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">15</span>
# <span class="emph"><span class="nHide">댓글수</span>(1114)</span>
# <a class="link" href="https://pann.nate.com/talk/372609027" onmousedown="nc('PAO94');objPannArea.clickContents(0);">민희진vs하이브 싸움에 껴드는거 아미들임</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">16</span>
# <span class="emph"><span class="nHide">댓글수</span>(43)</span>
# <a class="link" href="https://pann.nate.com/talk/372609493" onmousedown="nc('PAO95');objPannArea.clickContents(0);">라이즈 비율 왜이래……?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">17</span>
# <span class="emph"><span class="nHide">댓글수</span>(40)</span>
# <a class="link" href="https://pann.nate.com/talk/372608594" onmousedown="nc('PAO96');objPannArea.clickContents(0);">해린 명품 바이럴 날조 들킴</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">18</span>
# <span class="emph"><span class="nHide">댓글수</span>(32)</span>
# <a class="link" href="https://pann.nate.com/talk/372609209" onmousedown="nc('PAO97');objPannArea.clickContents(0);">권은비 연세대 왜 이러냐 ㄷㄷㄷ</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">19</span>
# <span class="emph"><span class="nHide">댓글수</span>(48)</span>
# <a class="link" href="https://pann.nate.com/talk/372609798" onmousedown="nc('PAO98');objPannArea.clickContents(0);">실시간 아카라카 라이즈</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">20</span>
# <span class="emph"><span class="nHide">댓글수</span>(129)</span>
# <a class="link" href="https://pann.nate.com/talk/372609880" onmousedown="nc('PAO99');objPannArea.clickContents(0);">존잘 남캐 짤털하자</a>
# </div>
# </li>
# </ol>
# </div>
# <!-- nav -->
# <div class="nav">
# <span><a href="//pann.nate.com/" onmousedown="nc('PAN65')">판홈</a> <i>|</i> <em>1</em> / 5</span>
# <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98')" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">이전 컨텐츠 보기</button>
# <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99')" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">다음 컨텐츠 보기</button>
# </div>
# <!-- //nav -->
# </div>
# <div class="area_issue" id="divIssueUp">
# <h3>키워드</h3>
# <div class="menu">
# <div class="keyword_list">
# <div class="list_top">
# <h4 class="menu08"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# <h4 class="menu01 on"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# <h4 class="menu02"><a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CTG02');">뷰티</a></h4>
# <h4 class="menu03"><a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG03');">푸드</a></h4>
# <h4 class="menu04"><a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">만화/웹툰</a></h4>
# <h4 class="menu05"><a href="javascript:issueContents.clickIssueUpCategory(5, 0)" onmousedown="nc('CTG05');">패션</a></h4>
# <h4 class="menu06"><a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CTG06');">라이프</a></h4>
# <h4 class="menu07" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# </div>
# <div class="list_btm" id="divIssueKeyword">
# <h5 class="on"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CCA01');">인생 등극</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 1)" onmousedown="nc('CCA02');">골라 먹는 뷔페</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 2)" onmousedown="nc('CCA03');">가성비 메뉴</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 3)" onmousedown="nc('CCA04');">현지인 추천</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 4)" onmousedown="nc('CCA05');">한정식</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 5)" onmousedown="nc('CCA06');">김밥 특집</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 6)" onmousedown="nc('CCA07');">SNS 인기</a></h5></div>
# </div>
# </div>
# <div class="content" id="divIssueUpContents">
# <ul><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '0');" onmousedown="nc5('CAA01','58217','65','1');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423852352.jpg" width="169"/></span><span class="title"><strong>사람들이 말하는</strong><br><strong>'1티어 순대' 후기</strong></br></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '1');" onmousedown="nc5('CAA02','58217','65','2');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423856622.jpg" width="169"/></span><span class="title">새롭고 독특한데<br>맛까지 만족!</br></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li class="type_wide"><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '2');" onmousedown="nc5('CAA03','58217','65','3');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423847801.jpg" width="356"/></span><span class="title"><strong>매우 쫄깃한 도우와 치즈가</strong><br/><strong>매력적인 '미쉐린' 선정 맛집</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '3');" onmousedown="nc5('CAA04','58217','65','4');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423833618.jpg" width="169"/></span><span class="title"><strong>마치 입궁한</strong><br/><strong>아씨가 된 기분?</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li class="type_text"><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '4');" onmousedown="nc5('CAA05','58217','65','5');nc2('CAA01');"><span class="title">한 그릇 싹 비운<br/>이영자 추천 메뉴<br/></span><span class="content">진짜 맛 괜찮아<br/>집 근처에 있다면<br/>매일 찾았을 듯</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '5');" onmousedown="nc5('CAA06','58217','65','6');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423861880.jpg" width="169"/></span><span class="title"><strong>강남 포장마차</strong><br/><strong>메뉴 중 단연 1등</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '6');" onmousedown="nc5('CAA07','58217','65','7');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716529070452.jpg" width="169"/></span><span class="title">분위기 좋은<br/>바다 앞 카페 발견</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li class="type_text"><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '7');" onmousedown="nc5('CAA08','58217','65','8');nc2('CAA01');"><span class="title">부산 여행 가면<br/>재방문 1순위<br/></span><span class="content">데이트 때 괜찮고<br/>부모님과 함께라면<br/>무조건 칭찬 예상?</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '8');" onmousedown="nc5('CAA09','58217','65','9');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423843906.jpg" width="169"/></span><span class="title"><strong>내장류 좋아한다면</strong><br/><strong>무조건 추천!</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://view.nate.com/travel/view/203575/', 'N', 1, 0);" onmousedown="nc5('CAA10','58217','65','10');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716423829311.jpg" width="169"/></span><span class="title">대만의 매력 담긴<br/>'인생 사진' 코스</span></a><cite>여행/맛집</cite></li><li><a href="javascript:;" onclick="issueContents.clickContents('https://view.nate.com/travel/view/140867/', 'N', 1, 0);" onmousedown="nc5('CAA11','58217',' ...
# <div class="content type_err nHide" id="emergencyLayer">
# <h4 class="">쇼핑탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>쇼핑탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="overlay_ally" style="display:none;"></div>
# <div class="movplay" id="movieSec">
# <div class="issuemov">
# <div id="divPlayer"></div>
# <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">광고 자세히보기</a>
# <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">동영상 플레이 레이어 닫기</button>
# </div>
# <span class="shadow"></span>
# </div>
# <div class="content type_err tbe nHide" id="divToonNBookErrLayer">
# <h4 class="">만화/웹툰탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>만화/웹툰탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://toonnbook.nate.com">네이트 툰앤북으로 바로가기</a>
# </div>
# </div>
# <div class="area_best">
# <h3>베스트 컨텐츠</h3>
# <h4>당신이 놓친 오늘의<br/>추천 콘텐츠</h4>
# <ul>
# <li>
# <a href="https://view.nate.com/enter/view/164386/" onmousedown="nc('RCM01');" title="결혼을 앞두고 취소 기자회견 준비도?">
# <span class="thumb">
# <img alt="결혼을 앞두고 취소 기자회견 준비도?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716181315999.jpg" width="94"/></span>
# <span class="title">
# 						결혼을 앞두고 취소 기자회견 준비도?
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20240520n01790" onmousedown="nc('RCM02');" title="군살 하나도 없어서 다이어트 대성공?">
# <span class="thumb">
# <img alt="군살 하나도 없어서 다이어트 대성공?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716181431998.jpg" width="94"/></span>
# <span class="title">
# 						군살 하나도 없어서 다이어트 대성공?
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20240517n02920" onmousedown="nc('RCM03');" title="건강한 습관 들이는 '갓생' 실천 식단">
# <span class="thumb">
# <img alt="건강한 습관 들이는 '갓생' 실천 식단" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716180000416.jpg" width="94"/></span>
# <span class="title">
# 						건강한 습관 들이는 '갓생' 실천 식단
# 						</span>
# <cite>
# 						 푸드
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20240509n43731" onmousedown="nc('RCM04');" title="풋풋한 느낌 그대로 '10대 임솔' 모습">
# <span class="thumb">
# <img alt="풋풋한 느낌 그대로 '10대 임솔' 모습" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716171088382.jpg" width="94"/></span>
# <span class="title">
# 						풋풋한 느낌 그대로 '10대 임솔' 모습
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# </ul>
# </div>
# <div class="area_ranking">
# <h3>랭킹</h3>
# <div class="menu">
# <h4 class="menu04">Fun &amp; Fun 해</h4>
# </div>
# <div class="content" onmouseout="nateRanking.startRolling()" onmouseover="nateRanking.stopRolling()">
# <ul class="type_thumb">
# <li>
# <a href="https://fortune.nate.com/content/contentInfo.nate?searchcontscd=CT000026" onmousedown="nc('RKN91')" title="운세ㅣ은밀한 사랑의 시그널"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716443792797.gif"/></span>
# <span class="title">운세ㅣ은밀한 사랑의 시그널<span class="cite">그의 행동 진심은 뭘까?</span></span></a>
# </li>
# <li>
# <a href="https://fortune.nate.com/contents/freeunse/freeunseframe.nate?freeUnseId=today03" onmousedown="nc('RKN92')" title="운세ㅣ열두 띠로 보는"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716443797107.gif"/></span>
# <span class="title">운세ㅣ열두 띠로 보는<span class="cite">2024년 05월 5주 운세</span></span></a>
# </li>
# <li>
# <a href="http://aa.nate.pupugame.com/" onmousedown="nc('RKN93')" title="나인엔젤 | 아홉 천사들과"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716443801886.jpg"/></span>
# <span class="title">나인엔젤 | 아홉 천사들과<span class="cite">천상계 전투에 참여하라!</span></span></a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H045476795" onmousedown="nc('RKN94')" title="만화 | 너는 선택받았다!"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716443806486.png"/></span>
# <span class="title">만화 | 너는 선택받았다!<span class="cite">악마개들</span></span></a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H045539959" onmousedown="nc('RKN95')" title="웹툰 | 보살펴주던 고양이가 천사"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716443811091.png"/></span>
# <span class="title">웹툰 | 보살펴주던 고양이가 천사<span class="cite">사랑하지 않는 세상의 유나씨</span></span></a>
# </li>
# </ul>
# </div>
# <div class="paging_slide">
# <span class="num_count_1"><em>1</em> / 2</span>
# <button class="btn prev" onclick="nateRanking.clickRankingBtn('P');" onmousedown="nc('RKN98');" title="이전" type="button">이전</button>
# <button class="btn next" onclick="nateRanking.clickRankingBtn('N');" onmousedown="nc('RKN99');" title="다음" type="button">다음</button>
# </div>
# </div>
# <hr/>
# <h2>쇼핑&amp; 광고 영역</h2>
# <div class="area_shopping" id="shopping" style="display:none">
# <h3>쇼핑</h3>
# <div class="mall1shop" id="shopitemMall">
# <h3 class="tab" id="mall1Title"><a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# <div class="shopmall" id="mall1Box"></div>
# <h3 class="tab" id="mall2Title"><a class="link" href="#" onmousedown="ndrclick2('NFC01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall2Box"></div>
# <h3 class="tab" id="mall3Title"><a class="link" href="#" onmousedown="ndrclick2('NFE01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall3Box"></div>
# <h3 class="tab" id="mall4Title"><a class="link" href="#" onmousedown="ndrclick2('NFG01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall4Box"></div>
# <div id="relShopping">
# <strong class="nHide">쇼핑 관련 리스트</strong>
# <div class="paging_slide">
# <button class="btn prev" id="shoppingPrev" onmousedown="ndrclick2('NFZ01')" title="이전" type="button">쇼핑 이전 내용</button>
# <button class="btn next" id="shoppingNext" onmousedown="ndrclick2('NFZ02')" title="다음" type="button">쇼핑 다음 내용</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
# </script>
# </div>
# <div class="area_shopping type_err" id="shopping_err" style="display:none">
# <h4 class="">쇼핑박스 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br/><strong>쇼핑박스는 지금 점검</strong> 중입니다.</br></p>
# <a href="http://shopping.nate.com">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="area_shopping_today">
# <!-- tiles:insertAttribute name="shopRecommendation" /-->
# </div>
# <div class="area_quick" id="divQuickMenu">
# <h3>퀵링크</h3>
# <div class="area_sktad01"></div>
# <ul>
# <li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
# <li>
# <a href="https://tv.nate.com/" onmousedown="nc('RAB25');" title="네이트TV 서비스 가기">네이트TV</a>
# </li>
# <li>
# <a href="https://m.ssul.nate.com/" onmousedown="nc('RAB26');" title="네이트썰 서비스 가기">네이트썰</a>
# </li>
# <li>
# <a href="https://mobile.nate.com/decorate/mvno/top" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">컬러링</a>
# </li>
# <li>
# <a href="http://editor.nate.com/" onmousedown="nc('RAB23');" title="이슈UP추천 서비스 가기">이슈UP추천</a>
# </li>
# <li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# </ul>
# </div>
# <div class="area_mallAd" id="divMallMenu"></div>
# </div>
# <hr/>
# <div id="footer">
# <h2>푸터 영역</h2>
# <div class="notice">
# <h3><a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">공지사항</a></h3>
# <a href="https://helpdesk.nate.com/web/notice/main-detail?id=8818" onmousedown="nc('NFT02');">'내편하자' 사연 모집 이벤트 오픈 안내</a>
# </div>
# <dl>
# <dt>네이트 공용 푸터</dt>
# <dd>
# <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# <a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# <a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# <a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# <span class="copyright">© <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT41');" target="_blank"><strong><span class="sk">SK</span> Communications.</strong></a></span>
# </dd>
# </dl>
# <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# <hr/>
# <div id="adContainer">
# <h2>광고 영역</h2>
# <div class="area_ad01" id="ad_layer1"></div>
# <div class="area_ad02" id="ad_layer2">
# </div>
# <div class="area_adual">
# <div class="area_ad03">
# </div>
# <div class="area_ad04">
# </div>
# </div>
# <div class="area_ad05 nHide" id="leftAd05Cj">
# <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/></a>
# </div>
# <div class="area_ad06"></div>
# <div class="area_sktad02"></div>
# <div class="area_ad09">
# <!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
# </div>
# <div class="area_ad10">
# <a href="https://m.ssul.nate.com/" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img alt=" 네이트썰" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2024/05/1716514401160.png" width="332"/></a>
# </div>
# <div id="ad_layer3"></div>
# <div id="ad_layer4" style="display:none;"></div>
# </div>
# </div>
# <div id="cbContainer">
# <div class="area_ad08" id="cbLayer" style="display: none">
# <span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">NATE를 시작페이지로</a>
# </div>
# </div>
# </div>
# <div class="setting_moblie" id="plus_footer" style="display: none"></div>
# <span id="layerTemp"></span>
# <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
# <!--natemain-->
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script></body></html>

# %%
find_div = soup.find("div", id = "divGnb")
find_div
# Out:
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="chat1"><a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">AI챗</a><em class="beta">beta</em></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">툰앤북</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class=""><a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">네이트뷰</a></li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">판포토</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# <li><a href="//m.ssul.nate.com/" onmousedown="nc('NSD46');">썰</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>

# %%
find_div.find("li")
# Out:
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>

# %%
find_div.find_all("li")[0]
# Out:
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>

# %%
find_div.find_all("li")[1]
# Out:
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>

# %%
find_div.find_all("li")[2].text
# Out:
# '판'

# %%
find_div.find_all("li")[1].text
# Out:
# '뉴스'

# %%
# nate.com 에서 DIV 태그로 감싸진 class 가 area_gnb 인 내용들만(TEXT) 리스트로 변경하여 반환해 보세요.
# 1. find_all 에서 class 는 어떻게 사용하지?
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class
# class (x) 
# 출력 메일, 뉴스, 판, AI챗 ...
html = requests.get("https://www.nate.com/")
soup = bs(html.text, "html.parser")
find_div = soup.find("div", class_ = "area_gnb")

# %%
for i in find_div.find_all("li"):
    print(i.text)
# Out:
# 메일
# 뉴스
# 판
# AI챗beta
# TV
# 툰앤북
# 운세
# 게임
# 쇼핑
# 팀룸
# 네이트뷰
#
# 더보기
#
#
# 뉴스
# 날씨
# 스포츠
# 연예
# 아이돌24
# 랭킹뉴스
#
#
# 판
# 톡톡
# 판포토
# 팬톡
#
#
# 네이트온
# 네이트캐쉬
# 문자메시지
# 주소록
#
#
# 컬러링
# 이슈UP추천
# 썰
#
# 서비스 전체보기
# 더보기 닫기
#
#
# 뉴스
# 날씨
# 스포츠
# 연예
# 아이돌24
# 랭킹뉴스
# 판
# 톡톡
# 판포토
# 팬톡
# 네이트온
# 네이트캐쉬
# 문자메시지
# 주소록
# 컬러링
# 이슈UP추천
# 썰

# %%
find_div.find_all("li")[2].text
# Out:
# '판'

# %% [markdown]
# ## 3. Selector
# ### Selector
# - 태그 중에는 동일한 태그가 존재할 수있다.
# - 선택자(Selector)는 동일한 태그 여러 개 중에서도 각 태그를 구별할 수 있는 일종의 주소이다.
#
# ### Selector의 필요성
#
# ```html
# <div>
# 	<div>
# 		<span> Python </span>
# 		<span> Hello world </span>
# 	</div>
#
# 	<div>
# 		<span> Java </span>
# 		<span> Coffee </span>
# 	</div>
# <div>
# ```
#
# - <span> 태그는 다양한 내용을 담을 수 있다.
# - <span> 태그가 4개나 있어서 컴퓨터가 구분하기 어렵다. 이러한 문제를 해결하기 위해 선택자를 사용함.
#
# ```html
# <div id = "contents">
# 	<div class = "metadata1">
# 		<span class = "language"> Python </span>
# 		<span class = "project" > Hello world </span>
# 	</div>
#
# 	<div class = "metadata2">
# 		<span class = "language"> Java </span>
# 		<span class = "project"> Coffee </span>
# 	</div>
# <div>
# ```

# %% [markdown]
# ### id와 class
# - 태그의 선택자는 주로 id와 class를 사용
# - id는 어떤 요소의 고유한 값
#     - html에서도 id는 하나의 고유한 선택자로, __중복__ 되지 않고 하나만 존재한다.
#     - [참고](https://www.w3schools.com/html/html_id.asp)
# - class 태그는 같은 속성을 지닌 데이터를 묶어주는 값
#     - 한 태그가 __여러 개__ 의 class를 가질 수 있다.
#     - [참고](https://www.w3schools.com/html/html_classes.asp)
#
# 비슷한 속성끼리 묶어줄 때 class 태그를 사용한다.

# %% [markdown]
# ### Selector 사용법
# ```html
# <div id='123' class='456'>
# ```
# - 선택자에 따라 데이터를 찾는 코드에 차이가 있다.
# - id는 '#'를 붙이고, class는 '.'을 붙여준다.
#
# - 태그만 사용해 데이터를 찾을 경우 -> 태그
#   - div
# - 태그와 id를 사용해 데이터를 찾을 경우 -> 태그#id
#   - div#123
# - 태그와 class를 사용해 데이터를 찾을 경우 -> 태그.class
#   - div.456
# - 태그, id, class 모두 사용해 데이터를 찾을 경우 -> 태그#id.class
#   - div#123.456
#
# - 참고 : class 이름에 공백이 포함될 경우가 종종 있는데, 이럴 경우 공백을 .으로 대체해서 작성하면 된다.
#     - ex)
#
#     ```html
#     <div class='hello python'>
#     ```
#
#     -> div.hello.python

# %%
# css selector 를 이용해 찾는 방법
css_selector = soup.select("#divGnb > ul")

# %%
css_selector[0].find_all("a")[0].text
# Out:
# '메일'

# %%
for i in css_selector[0].find_all("a"):
    print(i.text)
# Out:
# 메일
# 뉴스
# 판
# AI챗
# TV
# 툰앤북
# 운세
# 게임
# 쇼핑
# 팀룸
# 네이트뷰
# 더보기
# 뉴스
# 날씨
# 스포츠
# 연예
# 아이돌24
# 랭킹뉴스
# 판
# 톡톡
# 판포토
# 팬톡
# 네이트온
# 네이트캐쉬
# 문자메시지
# 주소록
# 컬러링
# 이슈UP추천
# 썰
# 서비스 전체보기

# %% [markdown]
# <!-- 과제 -->
#
# # 멜론차트
# # 원하는 장르를 입력 하세요 : 발라드
# # 순위 ~ 50위 까지만 하세요
# # 1 가수 제목
# # 2 가수
# # ...
# # 작성후 메일로 제출 (동작 화면 캡쳐 및 코드 캡쳐)
# # 그냥 python code로 작성 or gui 로 변경(pyqt 사용)
#
# ```python
# def get_gens(melon_url=melon_url, header=header):
#     pass # return 장르 url
# def get_table(url, header=header):
#     pass # return singers, songs()def  3. print_tasingers, songsb:
#     pass # 순위 가수 노래 출력     le()
#
# # 4. main() -> get_gens() -> get_table() -> print_table()
# ``` 제목
