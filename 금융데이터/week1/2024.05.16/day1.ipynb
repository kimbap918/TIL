# %%
# https://wikidocs.net/book/1

# %%
print("hello world")
# Out:
# hello world

# %%
# markdown 문법 (주석)

# %% [markdown]
# # markdown 문법
# ## docs
# - [markdown docs link](https://gist.github.com/ihoneymon/652be052a0727ad59601)
# - 아 배부르다.
# - 잘먹었다
#     - 두루치기
#     - 김치찌개

# %% [markdown]
# # 손흥민 사진
# ![아쉬워 하는 손흥민](https://imgnews.pstatic.net/image/088/2024/05/16/0000878151_002_20240516121001264.jpg)

# %% [markdown]
# # latex
# $$y = f(x_1, x_2)$$

# %% [markdown]
# ```python
# print("hello world")
# ```

# %% [markdown]
# - cell -> esc -> command mode -> m -> markdown cell 로 변경
# - cell -> esc -> command mode -> b -> 하단 code cell 추가
# - cell -> esc -> command mode -> a -> 상단 code cell 추가

# %%
# 인트로스펙션
# print("hello world")
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
# ?? : 정확한 정보
print??
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
 a = [1,2,3,4]

# %%
# 객체 정보 확인
a?
# Out:
# Type:        list
# String form: [1, 2, 3, 4]
# Length:      4
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
# list object 의 정보 출력
help(a)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
def func_1(x_1, x_2):
    return x_1 + x_2

# %%
func_1?
# Out:
# Signature: func_1(x_1, x_2)
# Docstring: <no docstring>
# File:      c:\users\ohminy\appdata\local\temp\ipykernel_3436\912106891.py
# Type:      function

# %%
func_1??
# Out:
# Signature: func_1(x_1, x_2)
# Docstring: <no docstring>
# Source:
# def func_1(x_1, x_2):
#     return x_1 + x_2
# File:      c:\users\ohminy\appdata\local\temp\ipykernel_3436\912106891.py
# Type:      function

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
# %timeit [i for i in range(1000)]
# Out:
# 81 µs ± 13.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %pwd
# Out:
# 'C:\\Users\\ohminy\\Desktop\\sesac\\1_python'

# %% [markdown]
# # 정리
# - windows 계정 영문으로 만들기 -> 관리자 권한 부여
# - Anaconda 설치 -> 가상환경 만들기 -> notebook 만들기
# - jupyternotebook 기능
#     - 인트로스펙션
#     - markdown 문법 사용가

# %%
# def : 함수를 정의하는 예약어
def = 1 # def 라는 변수에 1이라는 값을 맵핑시킨다.
# Out:
#   Cell In[18], line 2
#     def = 1 # def 라는 변수에 1이라는 값을 맵핑시킨다.
#         ^
# SyntaxError: invalid syntax

# %%
class = "hello" # class 라는 변수에 hello 라는 값을 맵핑시킨다.
# Out:
#   Cell In[19], line 1
#     class = "hello" # class 라는 변수에 hello 라는 값을 맵핑시킨다.
#           ^
# SyntaxError: invalid syntax

# %%
hello+world = "hello world"
# Out:
#   Cell In[20], line 1
#     hello+world = "hello world"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
hello-world = "hello world"
# Out:
#   Cell In[21], line 1
#     hello-world = "hello world"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
hello_world = "hello world"

# %%
hello_world
# Out:
# 'hello world'

# %%
hello_world2 = "hello world"

# %%
hello_world2
# Out:
# 'hello world'

# %%
2hello_world = "hello world"
# Out:
#   Cell In[27], line 1
#     2hello_world = "hello world"
#     ^
# SyntaxError: invalid decimal literal

# %%
hello world = "hello + world"
# Out:
#   Cell In[29], line 1
#     hello world = "hello + world"
#           ^
# SyntaxError: invalid syntax

# %%
val_1 = 123
models = ["model_1", "model_2"]

# %%
models
# Out:
# ['model_1', 'model_2']

# %%
# 연산자
1+2
# Out:
# 3

# %%
result_1 = 1+2

# %%
result_1
# Out:
# 3

# %%
print("hello world")
# Out:
# hello world

# %%
print(result_1)
# Out:
# 3

# %%
# 입력 
# input?
# input??
# help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
input_val  = input("값을 입력하세요 : ")
# Out:
# 값을 입력하세요 :  1999

# %%
print("저는 ", input_val, "년에 태어났습니다")
# Out:
# 저는  1999 년에 태어났습니다

# %%
# 태어난 연도를 입력하세요 : 1985
# 출력 : 저는 1985 년에 태어났습니다. 
# 출력 : 저는 40 살입니다. 
# 참고 int() 함수, str() 함수 참고

# %%
year = input("태어난 연도를 입력하세요 :")
old = 2024 - int(year) + 1
print("저는", year, "년에 태어났습니다.")
print("저는", old, "살 입니다. ")
# Out:
# 태어난 연도를 입력하세요 : 1985
# 저는 1985 년에 태어났습니다.
# 저는 40 살 입니다.

# %%
print("저는", year, "년에 태어났습니다.")
print(f"저는 {year} 년에 태어났습니다.")
# Out:
# 저는 1985 년에 태어났습니다.
# 저는 1985 년에 태어났습니다.

# %%
# 40분에 시작

# %%
type(year)
# Out:
# str

# %%
type(int(year))
# Out:
# int

# %%
# 같은 type 간의 연산
3 + 4
# Out:
# 7

# %%
3-6
# Out:
# -3

# %%
"hello" + "world"
# Out:
# 'helloworld'

# %%
"hello" + "hello"
# Out:
# 'hellohello'

# %%
"hello" * 3
# Out:
# 'hellohellohello'

# %%
# 수 
# 정수 : 양의 정수(자연수), 0, 음의 정수
# 실수 : 소수점이 붙은수 (FLOAT)

# %%
type(1.0)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
type(1.3444444)
# Out:
# float

# %%
type(1.3333e4) # e: 숫자 10
# Out:
# float

# %%
1.3333e-4
# Out:
# 0.00013333

# %%
# 질문 : 부동소수점이란 무엇인가요? , 파이썬에서는 부동소수점을 어떻게 표현 하나요?

# %%
# 연산자 : + , -, *, **, / , //, %

# %%
7//3 #몫
# Out:
# 2

# %%
7%3 #나머지
# Out:
# 1

# %%
"hello world"*3
# Out:
# 'hello worldhello worldhello world'

# %%
"hello world"/"hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 "hello world"/"hello"
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
"hellohello"%"hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 "hellohello"%"hello"
#
# TypeError: not all arguments converted during string formatting

# %%
type(2/4)
# Out:
# float

# %%
type(2.0/4.0)
# Out:
# float

# %%
1.0 == 1 # 대소비교
# Out:
# True

# %%
1.2 <= 1 # 대소비교
# Out:
# False

# %%
1.2 >= 1 # 대소비교
# Out:
# True

# %%
1.0 == 1
# Out:
# True

# %%
1.0 is 1
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ohminy\AppData\Local\Temp\ipykernel_3436\3505568189.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1.0 is 1
# False

# %%
# 0b11010?
0*(2**0) + 1*(2**1) + 0*(2**2) + 1*(2**3) + 1*(2**4)
# Out:
# 26

# %%
bin(26)
# Out:
# '0b11010'

# %%
# 0o11010?
0*(8**0) + 1*(8**1) + 0*(8**2) + 1*(8**3) + 1*(8**4)
# Out:
# 4616

# %%
oct(4616)
# Out:
# '0o11010'
