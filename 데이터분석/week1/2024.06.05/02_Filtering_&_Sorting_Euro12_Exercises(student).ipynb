# %% [markdown]
# ### Euro2012

# %% [markdown]
# ### Step 1. 필요한 라이브러리 들을 import 하세요

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. 다음 주소의 파일을 import 하세요 [address](https://raw.githubusercontent.com/myoh0623/dataset/main/Euro_2012_stats_TEAM.csv).

# %%
url = "https://raw.githubusercontent.com/myoh0623/dataset/main/Euro_2012_stats_TEAM.csv"

# %% [markdown]
# ### Step 3.euro12 라는 변수에 DataFrame을 할당하세요

# %%
euro12 = pd.read_csv(url)

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [raw]
# # Step 4. Goal column을 출력하세요

# %%
euro12.columns[1]
# Out:
# 'Goals'

# %%
euro12[euro12.columns[1]]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 5. Euro2012에는 몇팀이 참가 했습니까?

# %%
euro12.shape[0]
# Out:
# 16

# %%
len(euro12)
# Out:
# 16

# %%
len(set(euro12[euro12.columns[0]]))
# Out:
# 16

# %% [markdown]
# ### Step 6. Dataset의 컬럼은 몇개 인가요?

# %%
euro12.shape
# Out:
# (16, 35)

# %%
euro12.shape[1]
# Out:
# 35

# %% [markdown]
# ### Step 7. discipline 변수에 각 Team 당 Yellow Cards, Red Cards 을 dataframe으로 할당하여라

# %%
discipline = euro12[euro12.columns[[0, -5, -4]]]

# %%
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 8. Red Cards로 정렬한 다음 Yellow Cards로 정렬하시오

# %%
by_r_y = list(discipline.columns[[2, 1]])

# %%
# discipline.sort_values(by = by_r_y, ascending=False)
discipline.sort_values(by = by_r_y, ascending=True)
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# ### Step 9. 팀당 평균 Yellow Cards 는 얼마인가?

# %%
discipline["Yellow Cards"].mean()
# Out:
# 7.4375

# %%
round(discipline["Yellow Cards"].mean())
# Out:
# 7

# %% [markdown]
# ### Step 10. 6골이상 득점한 팀을 필터링 하시오

# %%
# 이상 : >=, 이하 <= , 초과 >, 미만 > 
euro12[euro12.Goals >=6]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# ...

# %% [markdown]
# ### Step 11."G" 로 시작하는 팀을 선택하시오

# %%
euro12[euro12.Team.str.startswith(("g", "G"))]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Step 12. DataFrame의 처음부터 7번째 column 까지 출력하시오

# %%
euro12.iloc[:, :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. 마지막 3개를 제외한 모든 columns 을 선택하시오

# %%
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. England, Italy, Russia의 슈팅 정확도를 출력하시오

# %%
euro12_shoot = euro12.copy()

# %%
euro12_shoot.set_index("Team", inplace=True)

# %%
euro12_shoot.loc[["England", "Italy", "Russia"],euro12_shoot.columns[[0,3]]]
# Out:
#          Goals Shooting Accuracy
# Team
# England      5             50.0%
# Italy        6             43.0%
# Russia       5             22.5%

# %%
euro12_shoot.loc[["England", "Italy", "Russia"],euro12_shoot.columns[[3]]]
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %%
# 35분에 시작합니다.
